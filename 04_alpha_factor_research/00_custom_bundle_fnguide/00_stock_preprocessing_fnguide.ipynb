# %% [markdown]
# # Zipline Custome Bundle 생성
# 기존에 Zipline Bundle은 미국주식으로만 되어 있었다. 국내주식을 이용하시 위해서 한국주식으로 되어 있는 custom bundle을 생성해서 사용해보도록 하자
# ### FN Guide 데이터는 유료이므로 유료 구독한 사람들을 위해서 생성했다.

# %% [markdown]
# ## Import & Settings

# %%
from pathlib import Path 
import warnings 
import pandas as pd

# %%
warnings.filterwarnings('ignore')
DATA_DIR = Path('..', '..', 'data')
idx = pd.IndexSlice

# %%
def create_split_table():
    with pd.HDFStore('fnguide.h5') as store:
        store.put('kr/splits', pd.DataFrame(columns=['sid', 'effective_date', 'ratio'],
                                            data=[[1, pd.to_datetime('1990-01-01'), 1.0]]), format='t')

# %%
def load_prices():
    df = pd.read_hdf(DATA_DIR / 'fnguide_data.h5', 'fnguide/prices')

    return (df
            .rename(columns=lambda x: x.replace('adj_', ''))
            .unstack('ticker')
            .sort_index()
            .tz_localize('UTC')
            .stack('ticker')
            .swaplevel()
            .astype('int64')
           )

# %%
def load_symbols(tickers):
    df = pd.read_hdf(DATA_DIR / 'fnguide_data.h5', 'fnguide/stocks')
    df = df.append(pd.DataFrame([['kospi', 'KOSPI']], columns=['ticker','name']))
    df.set_index('ticker', inplace=True)
    df = df.reindex(index=tickers)
    df.reset_index(inplace=True)
    return (df
            .reset_index(drop=True)
            .reset_index()
            .rename(columns={'index': 'sid'})[['sid', 'ticker',	'name']]
           )

# %% [markdown]
# ## 가격 데이터 불러오기

# %%
prices = load_prices()

# %%
date_index = prices.index.get_level_values('date').unique()

# %% [markdown]
# ## 벤치마크 데이터 추가

# %%
import FinanceDataReader as fdr
kospi = fdr.DataReader('KS11')

# %%
kospi
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 1981-05-01   123.60   123.60   123.60   123.60    3330000.0  0.0098
# 1981-05-02   123.50   123.50   123.50   123.50    2040000.0 -0.0008
# 1981-05-04   120.60   120.60   120.60   120.60    1930000.0 -0.0235
# 1981-05-06   120.70   120.70   120.70   120.70    1690000.0  0.0008
# 1981-05-07   119.30   119.30   119.30   119.30    1480000.0 -0.0116
# ...             ...      ...      ...      ...          ...     ...
# 2021-07-22  3250.21  3235.17  3253.75  3235.17  712980000.0  0.0107
# 2021-07-23  3254.42  3253.44  3264.01  3246.09  805050000.0  0.0013
# 2021-07-26  3224.95  3265.99  3265.99  3224.95  826070000.0 -0.0091
# 2021-07-27  3232.53  3244.43  3252.85  3230.75  991940000.0  0.0024
# 2021-07-28  3236.86  3226.06  3243.21  3210.90     856990.0  0.0013
#
# [10755 rows x 6 columns]

# %% [markdown]
# 데이터 전처리
# - timezone UTC처리
# - column 이름을 소문자로 변경

# %%
kospi['ticker'] = 'kospi'
kospi = kospi.tz_localize('UTC')
kospi_trading_date = kospi.index
kospi.reset_index(inplace=True)
kospi = kospi.rename(columns=lambda x: x.lower())

# %%
kospi = kospi.fillna(method='bfill')[['date', 'ticker', 'high',	'low', 'open', 'close', 'volume']]

# %%
kospi.set_index(['ticker', 'date'], inplace=True)

# %% [markdown]
# ## 주식 장 거래 날짜 수정
# - fnguide 데이터에서 휴장날인데 데이터가 온 것들이 있어서 이부분을 불러온 kospi 벤치마크 거래 날짜를 이용해서 클리닝 진행

# %%
kospi_trading_date = kospi.index.get_level_values('date')

# %%
prices_trading_date = prices.index.get_level_values('date').unique()

# %%
intersact_trading_date = kospi_trading_date.intersection(prices_trading_date)

# %%
kospi_trading_date.difference(prices_trading_date)
# Out:
# DatetimeIndex(['1981-05-01 00:00:00+00:00', '1981-05-02 00:00:00+00:00',
#                '1981-05-04 00:00:00+00:00', '1981-05-06 00:00:00+00:00',
#                '1981-05-07 00:00:00+00:00', '1981-05-08 00:00:00+00:00',
#                '1981-05-09 00:00:00+00:00', '1981-05-12 00:00:00+00:00',
#                '1981-05-13 00:00:00+00:00', '1981-05-14 00:00:00+00:00',
#                ...
#                '1998-10-17 00:00:00+00:00', '1998-10-24 00:00:00+00:00',
#                '1998-10-31 00:00:00+00:00', '1998-11-07 00:00:00+00:00',
#                '1998-11-14 00:00:00+00:00', '1998-11-21 00:00:00+00:00',
#                '1998-11-28 00:00:00+00:00', '1998-12-05 00:00:00+00:00',
#                '2021-07-27 00:00:00+00:00', '2021-07-28 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='date', length=2979, freq=None)

# %%
prices.sort_index(inplace=True)

# %%
prices = prices.unstack('ticker').reindex(index=intersact_trading_date).stack('ticker')

# %%
prices.index = prices.index.swaplevel()

# %%
prices
# Out:
#                                        high        low       open      close  \
# ticker date
# 000010 1990-01-03 00:00:00+00:00    42794.0    39737.0    39737.0    42794.0
# 000020 1990-01-03 00:00:00+00:00     1381.0     1381.0     1381.0     1381.0
# 000030 1990-01-03 00:00:00+00:00  1410887.0  1330265.0  1330265.0  1410887.0
# 000040 1990-01-03 00:00:00+00:00   874502.0   812481.0   812481.0   874502.0
# 000050 1990-01-03 00:00:00+00:00     1819.0     1819.0     1819.0     1819.0
# ...                                     ...        ...        ...        ...
# 380440 2021-07-26 00:00:00+00:00     2250.0     2220.0     2220.0     2245.0
# 383220 2021-07-26 00:00:00+00:00   626000.0   601000.0   621000.0   617000.0
# 383800 2021-07-26 00:00:00+00:00    10800.0    10600.0    10750.0    10650.0
# 900140 2021-07-26 00:00:00+00:00     3580.0     3505.0     3560.0     3520.0
# 950210 2021-07-26 00:00:00+00:00    29100.0    28700.0    29000.0    28700.0
#
#                                      volume
# ticker date
# 000010 1990-01-03 00:00:00+00:00   195060.0
# 000020 1990-01-03 00:00:00+00:00       10.0
# 000030 1990-01-03 00:00:00+00:00   208050.0
# 000040 1990-01-03 00:00:00+00:00    21760.0
# 000050 1990-01-03 00:00:00+00:00        0.0
# ...                                     ...
# 380440 2021-07-26 00:00:00+00:00  1257100.0
# 383220 2021-07-26 00:00:00+00:00    72589.0
# 383800 2021-07-26 00:00:00+00:00  1434272.0
# 900140 2021-07-26 00:00:00+00:00   356175.0
# 950210 2021-07-26 00:00:00+00:00  2478251.0
#
# [5446424 rows x 5 columns]

# %%
prices.index.names = ['ticker', 'date']

# %%
kospi = kospi.loc[idx[:, intersact_trading_date], :]

# %% [markdown]
# ### 가격 데이터와 벤치마크 데이터 연결

# %%
prices = pd.concat([prices, kospi]).sort_index()

# %%
prices
# Out:
#                                       high       low      open     close  \
# ticker date
# 000010 1990-01-03 00:00:00+00:00  42794.00  39737.00  39737.00  42794.00
#        1990-01-04 00:00:00+00:00  44628.00  42182.00  42794.00  44628.00
#        1990-01-05 00:00:00+00:00  45239.00  43711.00  44628.00  44016.00
#        1990-01-08 00:00:00+00:00  44016.00  43099.00  43711.00  43711.00
#        1990-01-09 00:00:00+00:00  44016.00  43405.00  43711.00  43405.00
# ...                                    ...       ...       ...       ...
# kospi  2021-07-20 00:00:00+00:00   3234.80   3214.42   3223.24   3232.70
#        2021-07-21 00:00:00+00:00   3252.25   3215.91   3251.13   3215.91
#        2021-07-22 00:00:00+00:00   3253.75   3235.17   3235.17   3250.21
#        2021-07-23 00:00:00+00:00   3264.01   3246.09   3253.44   3254.42
#        2021-07-26 00:00:00+00:00   3265.99   3224.95   3265.99   3224.95
#
#                                        volume
# ticker date
# 000010 1990-01-03 00:00:00+00:00     195060.0
#        1990-01-04 00:00:00+00:00     415700.0
#        1990-01-05 00:00:00+00:00     336870.0
#        1990-01-08 00:00:00+00:00     214660.0
#        1990-01-09 00:00:00+00:00     205280.0
# ...                                       ...
# kospi  2021-07-20 00:00:00+00:00  979670000.0
#        2021-07-21 00:00:00+00:00     973470.0
#        2021-07-22 00:00:00+00:00  712980000.0
#        2021-07-23 00:00:00+00:00  805050000.0
#        2021-07-26 00:00:00+00:00  826070000.0
#
# [5454200 rows x 5 columns]

# %%
tickers = prices.index.get_level_values('ticker').unique()

# %% [markdown]
# ## 주식 종목코드랑 이름 데이터 불러오기

# %%
symbols = load_symbols(tickers)

# %%
symbols
# Out:
#        sid  ticker        name
# 0        0  000010        조흥은행
# 1        1  000020        동화약품
# 2        2  000030        우리은행
# 3        3  000040       KR모터스
# 4        4  000050          경방
# ...    ...     ...         ...
# 1157  1157  950010    평산차업 KDR
# 1158  1158  950070        중국고섬
# 1159  1159  950100      SBI모기지
# 1160  1160  950210  프레스티지바이오파마
# 1161  1161   kospi       KOSPI
#
# [1162 rows x 3 columns]

# %% [markdown]
# ## **중요**  거래 정지 데이터(단기 과열등등)가 있어서 전처리
# - 주식 개장 날짜는 예를 들어 1월 3일, 4일 ,5일인데 단기 과열로 거래 정지된 종목들은 1월 3일, 5일과 같이 거래 정지된 4일이 비어있는 경우가 있다.
# - 이부분은 차후 zipline에서 ingest할때 실거래 일이랑 주식 가격데이터 거래일이랑 비교하므로 가격데이터 거래일이 거래정지되서 비어있으면 안된다. 따라서 ffill을 이용해서 앞의 가격으로 결측치 처리해주고 거래정지 이므로 volume은 0으로 넣어서 거래는 안됐다는 것을 전처리 해줬다.

# %%
def cleaning_data(ticker):
    stock_data = prices.loc[ticker]
    min_date = stock_data.index.min()
    max_date = stock_data.index.max()
    retrading_days = intersact_trading_date[(intersact_trading_date >= min_date) & (intersact_trading_date <= max_date)]
    stock_data = (stock_data
            .asfreq('1d')
            .reindex(index=retrading_days)
            )
    ohlc = stock_data[['high', 'low', 'open', 'close']].fillna(method='ffill')
    v = stock_data[['volume']].fillna(0)
    return pd.concat([ohlc, v], axis=1)

# %% [markdown]
# ## 데이터들 저장

# %%
for sid, symbol in symbols.set_index('sid').ticker.items():
    print(symbol)
    p = cleaning_data(symbol)
    p.to_hdf('fnguide.h5', 'kr/{}'.format(sid), format='t')
# Out:
# 000010
# 000020
# 000030
# 000040
# 000050
# 000060
# 000070
# 000080
# 000090
# 000100
# 000110
# 000120
# 000130
# 000140
# 000150
# 000160
# 000170
# 000180
# 000200
# 000210
# 000220
# 000230
# 000240
# 000270
# 000280
# 000300
# 000310
# 000320
# 000330
# 000360
# 000370
# 000390
# 000400
# 000420
# 000430
# 000450
# 000470
# 000480
# 000490
# 000500
# 000510
# 000520
# 000540
# 000570
# 000590
# 000600
# 000610
# 000640
# 000650
# 000660
# 000670
# 000680
# 000700
# 000720
# 000730
# 000760
# 000810
# 000830
# 000840
# 000850
# 000860
# 000870
# 000880
# 000890
# 000900
# 000910
# 000930
# 000950
# 000970
# 000990
# 001020
# 001030
# 001040
# 001060
# 001070
# 001080
# 001090
# 001120
# 001130
# 001140
# 001150
# 001160
# 001170
# 001190
# 001200
# 001210
# 001230
# 001250
# 001270
# 001280
# 001290
# 001300
# 001340
# 001350
# 001360
# 001370
# 001380
# 001390
# 001400
# 001420
# 001430
# 001440
# 001450
# 001460
# 001470
# 001500
# 001510
# 001520
# 001530
# 001550
# 001560
# 001570
# 001580
# 001600
# 001610
# 001620
# 001630
# 001670
# 001680
# 001690
# 001700
# 001720
# 001740
# 001750
# 001770
# 001780
# 001790
# 001800
# 001820
# 001830
# 001880
# 001910
# 001920
# 001930
# 001940
# 001950
# 001980
# 002000
# 002010
# 002020
# 002030
# 002050
# 002070
# 002080
# 002100
# 002130
# 002140
# 002150
# 002170
# 002180
# 002200
# 002210
# 002220
# 002240
# 002250
# 002270
# 002300
# 002310
# 002320
# 002340
# 002350
# 002360
# 002380
# 002390
# 002410
# 002420
# 002440
# 002450
# 002460
# 002530
# 002550
# 002600
# 002610
# 002620
# 002630
# 002690
# 002700
# 002710
# 002720
# 002730
# 002740
# 002760
# 002780
# 002790
# 002810
# 002820
# 002840
# 002850
# 002860
# 002870
# 002880
# 002900
# 002910
# 002920
# 002930
# 002940
# 002950
# 002960
# 002990
# 003000
# 003010
# 003020
# 003030
# 003040
# 003050
# 003070
# 003080
# 003090
# 003110
# 003120
# 003160
# 003190
# 003200
# 003220
# 003230
# 003240
# 003280
# 003290
# 003300
# 003320
# 003330
# 003350
# 003410
# 003450
# 003460
# 003470
# 003480
# 003490
# 003500
# 003520
# 003530
# 003540
# 003550
# 003560
# 003580
# 003590
# 003600
# 003610
# 003620
# 003640
# 003650
# 003660
# 003670
# 003680
# 003690
# 003720
# 003780
# 003810
# 003830
# 003840
# 003850
# 003900
# 003920
# 003930
# 003940
# 003960
# 003970
# 003990
# 004000
# 004010
# 004020
# 004060
# 004080
# 004090
# 004100
# 004110
# 004130
# 004140
# 004150
# 004170
# 004190
# 004200
# 004210
# 004230
# 004250
# 004260
# 004270
# 004280
# 004290
# 004310
# 004360
# 004370
# 004380
# 004390
# 004410
# 004430
# 004440
# 004450
# 004460
# 004490
# 004510
# 004530
# 004540
# 004550
# 004560
# 004600
# 004620
# 004660
# 004690
# 004700
# 004710
# 004720
# 004730
# 004740
# 004770
# 004800
# 004820
# 004830
# 004840
# 004870
# 004890
# 004910
# 004920
# 004940
# 004960
# 004970
# 004980
# 004990
# 005000
# 005010
# 005020
# 005030
# 005040
# 005060
# 005070
# 005090
# 005100
# 005110
# 005180
# 005190
# 005250
# 005270
# 005280
# 005300
# 005320
# 005330
# 005350
# 005360
# 005380
# 005390
# 005410
# 005420
# 005430
# 005440
# 005450
# 005490
# 005500
# 005510
# 005560
# 005580
# 005600
# 005610
# 005620
# 005660
# 005680
# 005690
# 005720
# 005740
# 005750
# 005760
# 005770
# 005790
# 005800
# 005810
# 005820
# 005830
# 005850
# 005870
# 005880
# 005890
# 005930
# 005940
# 005950
# 005960
# 005980
# 006040
# 006060
# 006070
# 006090
# 006110
# 006120
# 006150
# 006160
# 006200
# 006210
# 006220
# 006240
# 006250
# 006260
# 006270
# 006280
# 006290
# 006320
# 006340
# 006350
# 006360
# 006370
# 006380
# 006390
# 006400
# 006490
# 006510
# 006520
# 006540
# 006570
# 006590
# 006600
# 006610
# 006650
# 006660
# 006740
# 006750
# 006790
# 006800
# 006840
# 006880
# 006890
# 006900
# 006980
# 007000
# 007020
# 007050
# 007070
# 007100
# 007110
# 007120
# 007160
# 007170
# 007190
# 007200
# 007210
# 007230
# 007240
# 007280
# 007310
# 007340
# 007360
# 007380
# 007410
# 007420
# 007460
# 007480
# 007490
# 007540
# 007570
# 007590
# 007610
# 007630
# 007660
# 007690
# 007700
# 007790
# 007800
# 007810
# 007860
# 007910
# 007980
# 008000
# 008020
# 008040
# 008060
# 008100
# 008110
# 008190
# 008250
# 008260
# 008270
# 008320
# 008350
# 008420
# 008440
# 008480
# 008490
# 008500
# 008530
# 008540
# 008560
# 008600
# 008640
# 008650
# 008670
# 008700
# 008720
# 008730
# 008750
# 008770
# 008810
# 008870
# 008890
# 008900
# 008930
# 008950
# 008970
# 008980
# 008990
# 009030
# 009050
# 009070
# 009080
# 009140
# 009150
# 009160
# 009180
# 009190
# 009200
# 009240
# 009270
# 009290
# 009320
# 009330
# 009360
# 009380
# 009410
# 009420
# 009440
# 009450
# 009460
# 009470
# 009540
# 009580
# 009650
# 009680
# 009690
# 009720
# 009760
# 009770
# 009810
# 009830
# 009840
# 009890
# 009900
# 009940
# 009970
# 009990
# 010000
# 010030
# 010040
# 010050
# 010060
# 010100
# 010110
# 010120
# 010130
# 010140
# 010200
# 010220
# 010330
# 010400
# 010420
# 010460
# 010510
# 010520
# 010530
# 010580
# 010600
# 010620
# 010640
# 010660
# 010690
# 010730
# 010770
# 010780
# 010820
# 010910
# 010950
# 010960
# 010970
# 011000
# 011020
# 011050
# 011070
# 011090
# 011150
# 011160
# 011170
# 011180
# 011200
# 011210
# 011230
# 011260
# 011280
# 011290
# 011300
# 011330
# 011390
# 011420
# 011450
# 011470
# 011500
# 011510
# 011540
# 011650
# 011690
# 011700
# 011720
# 011760
# 011780
# 011790
# 011800
# 011810
# 011820
# 011840
# 011880
# 011930
# 011940
# 011960
# 012030
# 012090
# 012150
# 012160
# 012170
# 012190
# 012200
# 012220
# 012250
# 012260
# 012270
# 012280
# 012320
# 012330
# 012400
# 012410
# 012420
# 012450
# 012470
# 012500
# 012510
# 012600
# 012610
# 012630
# 012690
# 012710
# 012720
# 012750
# 012800
# 012830
# 012910
# 012990
# 013000
# 013040
# 013070
# 013200
# 013240
# 013250
# 013360
# 013520
# 013570
# 013580
# 013700
# 013820
# 013870
# 013890
# 014010
# 014040
# 014080
# 014130
# 014150
# 014160
# 014280
# 014300
# 014350
# 014390
# 014400
# 014430
# 014440
# 014450
# 014490
# 014530
# 014580
# 014590
# 014680
# 014710
# 014740
# 014790
# 014820
# 014830
# 014900
# 014910
# 014980
# 014990
# 015020
# 015080
# 015110
# 015230
# 015260
# 015340
# 015350
# 015360
# 015580
# 015590
# 015620
# 015650
# 015670
# 015730
# 015760
# 015780
# 015860
# 015880
# 015890
# 015940
# 015980
# 016070
# 016090
# 016160
# 016350
# 016360
# 016380
# 016390
# 016420
# 016430
# 016450
# 016480
# 016500
# 016510
# 016550
# 016560
# 016570
# 016580
# 016590
# 016610
# 016640
# 016680
# 016690
# 016710
# 016740
# 016800
# 016830
# 016880
# 016970
# 017040
# 017070
# 017110
# 017120
# 017180
# 017300
# 017320
# 017370
# 017390
# 017550
# 017670
# 017800
# 017810
# 017900
# 017940
# 017960
# 018020
# 018250
# 018260
# 018410
# 018470
# 018500
# 018550
# 018570
# 018590
# 018670
# 018880
# 019170
# 019180
# 019230
# 019300
# 019380
# 019440
# 019490
# 019680
# 019930
# 020000
# 020100
# 020120
# 020150
# 020560
# 020760
# 021050
# 021170
# 021240
# 021820
# 021960
# 022520
# 023000
# 023130
# 023150
# 023350
# 023450
# 023530
# 023590
# 023800
# 023810
# 023960
# 024070
# 024090
# 024100
# 024110
# 024720
# 024870
# 024890
# 024900
# 024960
# 025000
# 025530
# 025540
# 025560
# 025610
# 025750
# 025820
# 025830
# 025840
# 025850
# 025860
# 025890
# 025930
# 026870
# 026890
# 026940
# 026960
# 027390
# 027410
# 027460
# 027740
# 027840
# 027970
# 028050
# 028100
# 028260
# 028670
# 029460
# 029530
# 029780
# 029890
# 030000
# 030200
# 030210
# 030610
# 030710
# 030720
# 030790
# 031430
# 031440
# 031820
# 032350
# 032390
# 032560
# 032640
# 032710
# 032830
# 033180
# 033240
# 033250
# 033270
# 033530
# 033660
# 033780
# 033920
# 034020
# 034120
# 034220
# 034300
# 034310
# 034590
# 034730
# 034830
# 035000
# 035150
# 035250
# 035420
# 035510
# 035720
# 036420
# 036460
# 036530
# 036570
# 036580
# 037270
# 037560
# 037620
# 037710
# 038400
# 039130
# 039490
# 039570
# 041650
# 042100
# 042660
# 042670
# 042700
# 044380
# 044450
# 044820
# 045710
# 045820
# 047040
# 047050
# 047400
# 047810
# 049770
# 049800
# 051310
# 051600
# 051630
# 051900
# 051910
# 052690
# 053000
# 053210
# 053690
# 055490
# 055550
# 057050
# 058430
# 058650
# 058730
# 058850
# 058860
# 060000
# 060980
# 063160
# 063350
# 063510
# 064350
# 064420
# 064960
# 066570
# 067250
# 067830
# 068270
# 068290
# 068400
# 068870
# 069260
# 069460
# 069470
# 069620
# 069640
# 069730
# 069960
# 070960
# 071050
# 071090
# 071320
# 071840
# 071950
# 071970
# 072130
# 072710
# 073240
# 074610
# 075180
# 075580
# 076170
# 077500
# 077970
# 078000
# 078520
# 078930
# 079160
# 079430
# 079440
# 079550
# 079660
# 079980
# 081000
# 081660
# 082640
# 082740
# 083420
# 084010
# 084670
# 084680
# 084690
# 084870
# 085310
# 085620
# 086280
# 086790
# 088350
# 088790
# 089470
# 089590
# 090080
# 090350
# 090370
# 090430
# 091090
# 091810
# 092200
# 092220
# 092230
# 092440
# 092780
# 093050
# 093230
# 093240
# 093370
# 094280
# 095570
# 095720
# 096760
# 096770
# 097230
# 097520
# 097950
# 100220
# 100250
# 100840
# 101060
# 101140
# 101530
# 101990
# 102260
# 102280
# 102460
# 103130
# 103140
# 103150
# 103160
# 103590
# 104110
# 104120
# 104700
# 105560
# 105630
# 105840
# 107590
# 108070
# 108670
# 109070
# 110570
# 111110
# 111770
# 112610
# 114090
# 114410
# 115390
# 117580
# 117930
# 118000
# 119650
# 120030
# 120110
# 121910
# 122290
# 122750
# 122900
# 123690
# 123700
# 123890
# 126560
# 128820
# 128940
# 129260
# 130660
# 133820
# 134380
# 134790
# 136490
# 137310
# 138040
# 138250
# 138490
# 138930
# 139130
# 139480
# 143210
# 144620
# 145210
# 145720
# 145990
# 152330
# 155660
# 161000
# 161390
# 161890
# 163560
# 170900
# 175330
# 180640
# 181710
# 183190
# 185750
# 192080
# 192400
# 192520
# 192530
# 192650
# 192820
# 194370
# 195870
# 200880
# 204320
# 207940
# 210540
# 210980
# 213500
# 214320
# 214330
# 214390
# 214420
# 226320
# 227840
# 229640
# 234080
# 241560
# 241590
# 244920
# 248070
# 248170
# 249420
# 251270
# 264900
# 267250
# 267260
# 267270
# 267290
# 267850
# 268280
# 271560
# 271980
# 272210
# 272450
# 272550
# 280360
# 281820
# 282330
# 282690
# 284740
# 285130
# 286940
# 293480
# 294870
# 298000
# 298020
# 298040
# 298050
# 298690
# 300720
# 302440
# 306200
# 307950
# 308170
# 316140
# 317400
# 322000
# 326030
# 336260
# 336370
# 339770
# 344820
# 352820
# 353200
# 361610
# 363280
# 375500
# 378850
# 380440
# 383220
# 383800
# 900030
# 900050
# 900140
# 950010
# 950070
# 950100
# 950210
# kospi

# %%
symbols.to_hdf('fnguide.h5', 'kr/equities', format='t')

# %%
create_split_table()

# %%
prices.to_hdf('fnguide.h5', 'fnguide/prices/cleaning', format='t')

# %%
with pd.HDFStore('fnguide.h5') as store:
        print(store.info())
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: fnguide.h5
# /fnguide/prices/cleaning            frame_table  (typ->appendable_multi,nrows->5454200,ncols->7,indexers->[index],dc->[date,ticker])
# /kr/0                               frame_table  (typ->appendable,nrows->3550,ncols->5,indexers->[index],dc->[])
# /kr/1                               frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/10                              frame_table  (typ->appendable,nrows->3751,ncols->5,indexers->[index],dc->[])
# /kr/100                             frame_table  (typ->appendable,nrows->7488,ncols->5,indexers->[index],dc->[])
# /kr/1000                            frame_table  (typ->appendable,nrows->3328,ncols->5,indexers->[index],dc->[])
# /kr/1001                            frame_table  (typ->appendable,nrows->3323,ncols->5,indexers->[index],dc->[])
# /kr/1002                            frame_table  (typ->appendable,nrows->3302,ncols->5,indexers->[index],dc->[])
# /kr/1003                            frame_table  (typ->appendable,nrows->3295,ncols->5,indexers->[index],dc->[])
# /kr/1004                            frame_table  (typ->appendable,nrows->1283,ncols->5,indexers->[index],dc->[])
# /kr/1005                            frame_table  (typ->appendable,nrows->1485,ncols->5,indexers->[index],dc->[])
# /kr/1006                            frame_table  (typ->appendable,nrows->3242,ncols->5,indexers->[index],dc->[])
# /kr/1007                            frame_table  (typ->appendable,nrows->3251,ncols->5,indexers->[index],dc->[])
# /kr/1008                            frame_table  (typ->appendable,nrows->2748,ncols->5,indexers->[index],dc->[])
# /kr/1009                            frame_table  (typ->appendable,nrows->2446,ncols->5,indexers->[index],dc->[])
# /kr/101                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1010                            frame_table  (typ->appendable,nrows->3215,ncols->5,indexers->[index],dc->[])
# /kr/1011                            frame_table  (typ->appendable,nrows->790,ncols->5,indexers->[index],dc->[])
# /kr/1012                            frame_table  (typ->appendable,nrows->176,ncols->5,indexers->[index],dc->[])
# /kr/1013                            frame_table  (typ->appendable,nrows->3213,ncols->5,indexers->[index],dc->[])
# /kr/1014                            frame_table  (typ->appendable,nrows->2071,ncols->5,indexers->[index],dc->[])
# /kr/1015                            frame_table  (typ->appendable,nrows->2071,ncols->5,indexers->[index],dc->[])
# /kr/1016                            frame_table  (typ->appendable,nrows->3174,ncols->5,indexers->[index],dc->[])
# /kr/1017                            frame_table  (typ->appendable,nrows->3166,ncols->5,indexers->[index],dc->[])
# /kr/1018                            frame_table  (typ->appendable,nrows->3056,ncols->5,indexers->[index],dc->[])
# /kr/1019                            frame_table  (typ->appendable,nrows->2716,ncols->5,indexers->[index],dc->[])
# /kr/102                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1020                            frame_table  (typ->appendable,nrows->3070,ncols->5,indexers->[index],dc->[])
# /kr/1021                            frame_table  (typ->appendable,nrows->278,ncols->5,indexers->[index],dc->[])
# /kr/1022                            frame_table  (typ->appendable,nrows->3035,ncols->5,indexers->[index],dc->[])
# /kr/1023                            frame_table  (typ->appendable,nrows->3059,ncols->5,indexers->[index],dc->[])
# /kr/1024                            frame_table  (typ->appendable,nrows->1362,ncols->5,indexers->[index],dc->[])
# /kr/1025                            frame_table  (typ->appendable,nrows->1101,ncols->5,indexers->[index],dc->[])
# /kr/1026                            frame_table  (typ->appendable,nrows->2964,ncols->5,indexers->[index],dc->[])
# /kr/1027                            frame_table  (typ->appendable,nrows->1639,ncols->5,indexers->[index],dc->[])
# /kr/1028                            frame_table  (typ->appendable,nrows->2885,ncols->5,indexers->[index],dc->[])
# /kr/1029                            frame_table  (typ->appendable,nrows->143,ncols->5,indexers->[index],dc->[])
# /kr/103                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1030                            frame_table  (typ->appendable,nrows->2838,ncols->5,indexers->[index],dc->[])
# /kr/1031                            frame_table  (typ->appendable,nrows->2610,ncols->5,indexers->[index],dc->[])
# /kr/1032                            frame_table  (typ->appendable,nrows->1779,ncols->5,indexers->[index],dc->[])
# /kr/1033                            frame_table  (typ->appendable,nrows->2857,ncols->5,indexers->[index],dc->[])
# /kr/1034                            frame_table  (typ->appendable,nrows->2837,ncols->5,indexers->[index],dc->[])
# /kr/1035                            frame_table  (typ->appendable,nrows->2823,ncols->5,indexers->[index],dc->[])
# /kr/1036                            frame_table  (typ->appendable,nrows->2836,ncols->5,indexers->[index],dc->[])
# /kr/1037                            frame_table  (typ->appendable,nrows->654,ncols->5,indexers->[index],dc->[])
# /kr/1038                            frame_table  (typ->appendable,nrows->655,ncols->5,indexers->[index],dc->[])
# /kr/1039                            frame_table  (typ->appendable,nrows->654,ncols->5,indexers->[index],dc->[])
# /kr/104                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1040                            frame_table  (typ->appendable,nrows->2712,ncols->5,indexers->[index],dc->[])
# /kr/1041                            frame_table  (typ->appendable,nrows->2754,ncols->5,indexers->[index],dc->[])
# /kr/1042                            frame_table  (typ->appendable,nrows->2755,ncols->5,indexers->[index],dc->[])
# /kr/1043                            frame_table  (typ->appendable,nrows->1239,ncols->5,indexers->[index],dc->[])
# /kr/1044                            frame_table  (typ->appendable,nrows->2611,ncols->5,indexers->[index],dc->[])
# /kr/1045                            frame_table  (typ->appendable,nrows->2712,ncols->5,indexers->[index],dc->[])
# /kr/1046                            frame_table  (typ->appendable,nrows->2712,ncols->5,indexers->[index],dc->[])
# /kr/1047                            frame_table  (typ->appendable,nrows->2367,ncols->5,indexers->[index],dc->[])
# /kr/1048                            frame_table  (typ->appendable,nrows->2616,ncols->5,indexers->[index],dc->[])
# /kr/1049                            frame_table  (typ->appendable,nrows->1725,ncols->5,indexers->[index],dc->[])
# /kr/105                             frame_table  (typ->appendable,nrows->7668,ncols->5,indexers->[index],dc->[])
# /kr/1050                            frame_table  (typ->appendable,nrows->2577,ncols->5,indexers->[index],dc->[])
# /kr/1051                            frame_table  (typ->appendable,nrows->2589,ncols->5,indexers->[index],dc->[])
# /kr/1052                            frame_table  (typ->appendable,nrows->2576,ncols->5,indexers->[index],dc->[])
# /kr/1053                            frame_table  (typ->appendable,nrows->7,ncols->5,indexers->[index],dc->[])
# /kr/1054                            frame_table  (typ->appendable,nrows->2517,ncols->5,indexers->[index],dc->[])
# /kr/1055                            frame_table  (typ->appendable,nrows->1559,ncols->5,indexers->[index],dc->[])
# /kr/1056                            frame_table  (typ->appendable,nrows->2495,ncols->5,indexers->[index],dc->[])
# /kr/1057                            frame_table  (typ->appendable,nrows->2547,ncols->5,indexers->[index],dc->[])
# /kr/1058                            frame_table  (typ->appendable,nrows->2501,ncols->5,indexers->[index],dc->[])
# /kr/1059                            frame_table  (typ->appendable,nrows->2498,ncols->5,indexers->[index],dc->[])
# /kr/106                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1060                            frame_table  (typ->appendable,nrows->1142,ncols->5,indexers->[index],dc->[])
# /kr/1061                            frame_table  (typ->appendable,nrows->2292,ncols->5,indexers->[index],dc->[])
# /kr/1062                            frame_table  (typ->appendable,nrows->1565,ncols->5,indexers->[index],dc->[])
# /kr/1063                            frame_table  (typ->appendable,nrows->1073,ncols->5,indexers->[index],dc->[])
# /kr/1064                            frame_table  (typ->appendable,nrows->2376,ncols->5,indexers->[index],dc->[])
# /kr/1065                            frame_table  (typ->appendable,nrows->1221,ncols->5,indexers->[index],dc->[])
# /kr/1066                            frame_table  (typ->appendable,nrows->2017,ncols->5,indexers->[index],dc->[])
# /kr/1067                            frame_table  (typ->appendable,nrows->2180,ncols->5,indexers->[index],dc->[])
# /kr/1068                            frame_table  (typ->appendable,nrows->2169,ncols->5,indexers->[index],dc->[])
# /kr/1069                            frame_table  (typ->appendable,nrows->2158,ncols->5,indexers->[index],dc->[])
# /kr/107                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1070                            frame_table  (typ->appendable,nrows->2158,ncols->5,indexers->[index],dc->[])
# /kr/1071                            frame_table  (typ->appendable,nrows->2043,ncols->5,indexers->[index],dc->[])
# /kr/1072                            frame_table  (typ->appendable,nrows->1973,ncols->5,indexers->[index],dc->[])
# /kr/1073                            frame_table  (typ->appendable,nrows->1932,ncols->5,indexers->[index],dc->[])
# /kr/1074                            frame_table  (typ->appendable,nrows->1944,ncols->5,indexers->[index],dc->[])
# /kr/1075                            frame_table  (typ->appendable,nrows->1900,ncols->5,indexers->[index],dc->[])
# /kr/1076                            frame_table  (typ->appendable,nrows->1878,ncols->5,indexers->[index],dc->[])
# /kr/1077                            frame_table  (typ->appendable,nrows->1408,ncols->5,indexers->[index],dc->[])
# /kr/1078                            frame_table  (typ->appendable,nrows->1714,ncols->5,indexers->[index],dc->[])
# /kr/1079                            frame_table  (typ->appendable,nrows->266,ncols->5,indexers->[index],dc->[])
# /kr/108                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1080                            frame_table  (typ->appendable,nrows->1086,ncols->5,indexers->[index],dc->[])
# /kr/1081                            frame_table  (typ->appendable,nrows->588,ncols->5,indexers->[index],dc->[])
# /kr/1082                            frame_table  (typ->appendable,nrows->1796,ncols->5,indexers->[index],dc->[])
# /kr/1083                            frame_table  (typ->appendable,nrows->1345,ncols->5,indexers->[index],dc->[])
# /kr/1084                            frame_table  (typ->appendable,nrows->1252,ncols->5,indexers->[index],dc->[])
# /kr/1085                            frame_table  (typ->appendable,nrows->1712,ncols->5,indexers->[index],dc->[])
# /kr/1086                            frame_table  (typ->appendable,nrows->1676,ncols->5,indexers->[index],dc->[])
# /kr/1087                            frame_table  (typ->appendable,nrows->1158,ncols->5,indexers->[index],dc->[])
# /kr/1088                            frame_table  (typ->appendable,nrows->1607,ncols->5,indexers->[index],dc->[])
# /kr/1089                            frame_table  (typ->appendable,nrows->1500,ncols->5,indexers->[index],dc->[])
# /kr/109                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1090                            frame_table  (typ->appendable,nrows->1600,ncols->5,indexers->[index],dc->[])
# /kr/1091                            frame_table  (typ->appendable,nrows->1482,ncols->5,indexers->[index],dc->[])
# /kr/1092                            frame_table  (typ->appendable,nrows->1403,ncols->5,indexers->[index],dc->[])
# /kr/1093                            frame_table  (typ->appendable,nrows->1496,ncols->5,indexers->[index],dc->[])
# /kr/1094                            frame_table  (typ->appendable,nrows->1487,ncols->5,indexers->[index],dc->[])
# /kr/1095                            frame_table  (typ->appendable,nrows->1371,ncols->5,indexers->[index],dc->[])
# /kr/1096                            frame_table  (typ->appendable,nrows->1416,ncols->5,indexers->[index],dc->[])
# /kr/1097                            frame_table  (typ->appendable,nrows->1192,ncols->5,indexers->[index],dc->[])
# /kr/1098                            frame_table  (typ->appendable,nrows->1168,ncols->5,indexers->[index],dc->[])
# /kr/1099                            frame_table  (typ->appendable,nrows->1152,ncols->5,indexers->[index],dc->[])
# /kr/11                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/110                             frame_table  (typ->appendable,nrows->3865,ncols->5,indexers->[index],dc->[])
# /kr/1100                            frame_table  (typ->appendable,nrows->1185,ncols->5,indexers->[index],dc->[])
# /kr/1101                            frame_table  (typ->appendable,nrows->312,ncols->5,indexers->[index],dc->[])
# /kr/1102                            frame_table  (typ->appendable,nrows->120,ncols->5,indexers->[index],dc->[])
# /kr/1103                            frame_table  (typ->appendable,nrows->1220,ncols->5,indexers->[index],dc->[])
# /kr/1104                            frame_table  (typ->appendable,nrows->1205,ncols->5,indexers->[index],dc->[])
# /kr/1105                            frame_table  (typ->appendable,nrows->1035,ncols->5,indexers->[index],dc->[])
# /kr/1106                            frame_table  (typ->appendable,nrows->1054,ncols->5,indexers->[index],dc->[])
# /kr/1107                            frame_table  (typ->appendable,nrows->1037,ncols->5,indexers->[index],dc->[])
# /kr/1108                            frame_table  (typ->appendable,nrows->1037,ncols->5,indexers->[index],dc->[])
# /kr/1109                            frame_table  (typ->appendable,nrows->1037,ncols->5,indexers->[index],dc->[])
# /kr/111                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1110                            frame_table  (typ->appendable,nrows->1035,ncols->5,indexers->[index],dc->[])
# /kr/1111                            frame_table  (typ->appendable,nrows->660,ncols->5,indexers->[index],dc->[])
# /kr/1112                            frame_table  (typ->appendable,nrows->1029,ncols->5,indexers->[index],dc->[])
# /kr/1113                            frame_table  (typ->appendable,nrows->996,ncols->5,indexers->[index],dc->[])
# /kr/1114                            frame_table  (typ->appendable,nrows->990,ncols->5,indexers->[index],dc->[])
# /kr/1115                            frame_table  (typ->appendable,nrows->422,ncols->5,indexers->[index],dc->[])
# /kr/1116                            frame_table  (typ->appendable,nrows->893,ncols->5,indexers->[index],dc->[])
# /kr/1117                            frame_table  (typ->appendable,nrows->900,ncols->5,indexers->[index],dc->[])
# /kr/1118                            frame_table  (typ->appendable,nrows->922,ncols->5,indexers->[index],dc->[])
# /kr/1119                            frame_table  (typ->appendable,nrows->896,ncols->5,indexers->[index],dc->[])
# /kr/112                             frame_table  (typ->appendable,nrows->3824,ncols->5,indexers->[index],dc->[])
# /kr/1120                            frame_table  (typ->appendable,nrows->893,ncols->5,indexers->[index],dc->[])
# /kr/1121                            frame_table  (typ->appendable,nrows->900,ncols->5,indexers->[index],dc->[])
# /kr/1122                            frame_table  (typ->appendable,nrows->872,ncols->5,indexers->[index],dc->[])
# /kr/1123                            frame_table  (typ->appendable,nrows->876,ncols->5,indexers->[index],dc->[])
# /kr/1124                            frame_table  (typ->appendable,nrows->739,ncols->5,indexers->[index],dc->[])
# /kr/1125                            frame_table  (typ->appendable,nrows->696,ncols->5,indexers->[index],dc->[])
# /kr/1126                            frame_table  (typ->appendable,nrows->771,ncols->5,indexers->[index],dc->[])
# /kr/1127                            frame_table  (typ->appendable,nrows->749,ncols->5,indexers->[index],dc->[])
# /kr/1128                            frame_table  (typ->appendable,nrows->749,ncols->5,indexers->[index],dc->[])
# /kr/1129                            frame_table  (typ->appendable,nrows->749,ncols->5,indexers->[index],dc->[])
# /kr/113                             frame_table  (typ->appendable,nrows->4991,ncols->5,indexers->[index],dc->[])
# /kr/1130                            frame_table  (typ->appendable,nrows->749,ncols->5,indexers->[index],dc->[])
# /kr/1131                            frame_table  (typ->appendable,nrows->637,ncols->5,indexers->[index],dc->[])
# /kr/1132                            frame_table  (typ->appendable,nrows->733,ncols->5,indexers->[index],dc->[])
# /kr/1133                            frame_table  (typ->appendable,nrows->91,ncols->5,indexers->[index],dc->[])
# /kr/1134                            frame_table  (typ->appendable,nrows->694,ncols->5,indexers->[index],dc->[])
# /kr/1135                            frame_table  (typ->appendable,nrows->578,ncols->5,indexers->[index],dc->[])
# /kr/1136                            frame_table  (typ->appendable,nrows->414,ncols->5,indexers->[index],dc->[])
# /kr/1137                            frame_table  (typ->appendable,nrows->608,ncols->5,indexers->[index],dc->[])
# /kr/1138                            frame_table  (typ->appendable,nrows->427,ncols->5,indexers->[index],dc->[])
# /kr/1139                            frame_table  (typ->appendable,nrows->418,ncols->5,indexers->[index],dc->[])
# /kr/114                             frame_table  (typ->appendable,nrows->1654,ncols->5,indexers->[index],dc->[])
# /kr/1140                            frame_table  (typ->appendable,nrows->265,ncols->5,indexers->[index],dc->[])
# /kr/1141                            frame_table  (typ->appendable,nrows->440,ncols->5,indexers->[index],dc->[])
# /kr/1142                            frame_table  (typ->appendable,nrows->440,ncols->5,indexers->[index],dc->[])
# /kr/1143                            frame_table  (typ->appendable,nrows->175,ncols->5,indexers->[index],dc->[])
# /kr/1144                            frame_table  (typ->appendable,nrows->376,ncols->5,indexers->[index],dc->[])
# /kr/1145                            frame_table  (typ->appendable,nrows->195,ncols->5,indexers->[index],dc->[])
# /kr/1146                            frame_table  (typ->appendable,nrows->295,ncols->5,indexers->[index],dc->[])
# /kr/1147                            frame_table  (typ->appendable,nrows->54,ncols->5,indexers->[index],dc->[])
# /kr/1148                            frame_table  (typ->appendable,nrows->208,ncols->5,indexers->[index],dc->[])
# /kr/1149                            frame_table  (typ->appendable,nrows->126,ncols->5,indexers->[index],dc->[])
# /kr/115                             frame_table  (typ->appendable,nrows->7600,ncols->5,indexers->[index],dc->[])
# /kr/1150                            frame_table  (typ->appendable,nrows->94,ncols->5,indexers->[index],dc->[])
# /kr/1151                            frame_table  (typ->appendable,nrows->47,ncols->5,indexers->[index],dc->[])
# /kr/1152                            frame_table  (typ->appendable,nrows->47,ncols->5,indexers->[index],dc->[])
# /kr/1153                            frame_table  (typ->appendable,nrows->43,ncols->5,indexers->[index],dc->[])
# /kr/1154                            frame_table  (typ->appendable,nrows->946,ncols->5,indexers->[index],dc->[])
# /kr/1155                            frame_table  (typ->appendable,nrows->2074,ncols->5,indexers->[index],dc->[])
# /kr/1156                            frame_table  (typ->appendable,nrows->2628,ncols->5,indexers->[index],dc->[])
# /kr/1157                            frame_table  (typ->appendable,nrows->1973,ncols->5,indexers->[index],dc->[])
# /kr/1158                            frame_table  (typ->appendable,nrows->667,ncols->5,indexers->[index],dc->[])
# /kr/1159                            frame_table  (typ->appendable,nrows->663,ncols->5,indexers->[index],dc->[])
# /kr/116                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/1160                            frame_table  (typ->appendable,nrows->117,ncols->5,indexers->[index],dc->[])
# /kr/1161                            frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/117                             frame_table  (typ->appendable,nrows->3755,ncols->5,indexers->[index],dc->[])
# /kr/118                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/119                             frame_table  (typ->appendable,nrows->2949,ncols->5,indexers->[index],dc->[])
# /kr/12                              frame_table  (typ->appendable,nrows->2206,ncols->5,indexers->[index],dc->[])
# /kr/120                             frame_table  (typ->appendable,nrows->2230,ncols->5,indexers->[index],dc->[])
# /kr/121                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/122                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/123                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/124                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/125                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/126                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/127                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/128                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/129                             frame_table  (typ->appendable,nrows->4269,ncols->5,indexers->[index],dc->[])
# /kr/13                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/130                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/131                             frame_table  (typ->appendable,nrows->124,ncols->5,indexers->[index],dc->[])
# /kr/132                             frame_table  (typ->appendable,nrows->3009,ncols->5,indexers->[index],dc->[])
# /kr/133                             frame_table  (typ->appendable,nrows->2191,ncols->5,indexers->[index],dc->[])
# /kr/134                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/135                             frame_table  (typ->appendable,nrows->4866,ncols->5,indexers->[index],dc->[])
# /kr/136                             frame_table  (typ->appendable,nrows->3513,ncols->5,indexers->[index],dc->[])
# /kr/137                             frame_table  (typ->appendable,nrows->7130,ncols->5,indexers->[index],dc->[])
# /kr/138                             frame_table  (typ->appendable,nrows->1495,ncols->5,indexers->[index],dc->[])
# /kr/139                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/14                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/140                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/141                             frame_table  (typ->appendable,nrows->3269,ncols->5,indexers->[index],dc->[])
# /kr/142                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/143                             frame_table  (typ->appendable,nrows->2689,ncols->5,indexers->[index],dc->[])
# /kr/144                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/145                             frame_table  (typ->appendable,nrows->2920,ncols->5,indexers->[index],dc->[])
# /kr/146                             frame_table  (typ->appendable,nrows->7526,ncols->5,indexers->[index],dc->[])
# /kr/147                             frame_table  (typ->appendable,nrows->2703,ncols->5,indexers->[index],dc->[])
# /kr/148                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/149                             frame_table  (typ->appendable,nrows->2995,ncols->5,indexers->[index],dc->[])
# /kr/15                              frame_table  (typ->appendable,nrows->2405,ncols->5,indexers->[index],dc->[])
# /kr/150                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/151                             frame_table  (typ->appendable,nrows->7764,ncols->5,indexers->[index],dc->[])
# /kr/152                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/153                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/154                             frame_table  (typ->appendable,nrows->7233,ncols->5,indexers->[index],dc->[])
# /kr/155                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/156                             frame_table  (typ->appendable,nrows->7518,ncols->5,indexers->[index],dc->[])
# /kr/157                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/158                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/159                             frame_table  (typ->appendable,nrows->2405,ncols->5,indexers->[index],dc->[])
# /kr/16                              frame_table  (typ->appendable,nrows->2264,ncols->5,indexers->[index],dc->[])
# /kr/160                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/161                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/162                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/163                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/164                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/165                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/166                             frame_table  (typ->appendable,nrows->1933,ncols->5,indexers->[index],dc->[])
# /kr/167                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/168                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/169                             frame_table  (typ->appendable,nrows->5994,ncols->5,indexers->[index],dc->[])
# /kr/17                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/170                             frame_table  (typ->appendable,nrows->6790,ncols->5,indexers->[index],dc->[])
# /kr/171                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/172                             frame_table  (typ->appendable,nrows->3228,ncols->5,indexers->[index],dc->[])
# /kr/173                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/174                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/175                             frame_table  (typ->appendable,nrows->1434,ncols->5,indexers->[index],dc->[])
# /kr/176                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/177                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/178                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/179                             frame_table  (typ->appendable,nrows->2151,ncols->5,indexers->[index],dc->[])
# /kr/18                              frame_table  (typ->appendable,nrows->2786,ncols->5,indexers->[index],dc->[])
# /kr/180                             frame_table  (typ->appendable,nrows->2783,ncols->5,indexers->[index],dc->[])
# /kr/181                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/182                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/183                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/184                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/185                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/186                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/187                             frame_table  (typ->appendable,nrows->3502,ncols->5,indexers->[index],dc->[])
# /kr/188                             frame_table  (typ->appendable,nrows->3912,ncols->5,indexers->[index],dc->[])
# /kr/189                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/19                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/190                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/191                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/192                             frame_table  (typ->appendable,nrows->1034,ncols->5,indexers->[index],dc->[])
# /kr/193                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/194                             frame_table  (typ->appendable,nrows->3512,ncols->5,indexers->[index],dc->[])
# /kr/195                             frame_table  (typ->appendable,nrows->2570,ncols->5,indexers->[index],dc->[])
# /kr/196                             frame_table  (typ->appendable,nrows->3512,ncols->5,indexers->[index],dc->[])
# /kr/197                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/198                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/199                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/2                               frame_table  (typ->appendable,nrows->7168,ncols->5,indexers->[index],dc->[])
# /kr/20                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/200                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/201                             frame_table  (typ->appendable,nrows->3525,ncols->5,indexers->[index],dc->[])
# /kr/202                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/203                             frame_table  (typ->appendable,nrows->4146,ncols->5,indexers->[index],dc->[])
# /kr/204                             frame_table  (typ->appendable,nrows->3670,ncols->5,indexers->[index],dc->[])
# /kr/205                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/206                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/207                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/208                             frame_table  (typ->appendable,nrows->3009,ncols->5,indexers->[index],dc->[])
# /kr/209                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/21                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/210                             frame_table  (typ->appendable,nrows->6167,ncols->5,indexers->[index],dc->[])
# /kr/211                             frame_table  (typ->appendable,nrows->5751,ncols->5,indexers->[index],dc->[])
# /kr/212                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/213                             frame_table  (typ->appendable,nrows->6340,ncols->5,indexers->[index],dc->[])
# /kr/214                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/215                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/216                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/217                             frame_table  (typ->appendable,nrows->2405,ncols->5,indexers->[index],dc->[])
# /kr/218                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/219                             frame_table  (typ->appendable,nrows->2861,ncols->5,indexers->[index],dc->[])
# /kr/22                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/220                             frame_table  (typ->appendable,nrows->4128,ncols->5,indexers->[index],dc->[])
# /kr/221                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/222                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/223                             frame_table  (typ->appendable,nrows->6611,ncols->5,indexers->[index],dc->[])
# /kr/224                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/225                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/226                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/227                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/228                             frame_table  (typ->appendable,nrows->2046,ncols->5,indexers->[index],dc->[])
# /kr/229                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/23                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/230                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/231                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/232                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/233                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/234                             frame_table  (typ->appendable,nrows->7721,ncols->5,indexers->[index],dc->[])
# /kr/235                             frame_table  (typ->appendable,nrows->3563,ncols->5,indexers->[index],dc->[])
# /kr/236                             frame_table  (typ->appendable,nrows->6314,ncols->5,indexers->[index],dc->[])
# /kr/237                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/238                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/239                             frame_table  (typ->appendable,nrows->6170,ncols->5,indexers->[index],dc->[])
# /kr/24                              frame_table  (typ->appendable,nrows->2796,ncols->5,indexers->[index],dc->[])
# /kr/240                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/241                             frame_table  (typ->appendable,nrows->4575,ncols->5,indexers->[index],dc->[])
# /kr/242                             frame_table  (typ->appendable,nrows->4880,ncols->5,indexers->[index],dc->[])
# /kr/243                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/244                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/245                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/246                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/247                             frame_table  (typ->appendable,nrows->2786,ncols->5,indexers->[index],dc->[])
# /kr/248                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/249                             frame_table  (typ->appendable,nrows->2388,ncols->5,indexers->[index],dc->[])
# /kr/25                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/250                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/251                             frame_table  (typ->appendable,nrows->3473,ncols->5,indexers->[index],dc->[])
# /kr/252                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/253                             frame_table  (typ->appendable,nrows->3547,ncols->5,indexers->[index],dc->[])
# /kr/254                             frame_table  (typ->appendable,nrows->6421,ncols->5,indexers->[index],dc->[])
# /kr/255                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/256                             frame_table  (typ->appendable,nrows->1732,ncols->5,indexers->[index],dc->[])
# /kr/257                             frame_table  (typ->appendable,nrows->4749,ncols->5,indexers->[index],dc->[])
# /kr/258                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/259                             frame_table  (typ->appendable,nrows->5681,ncols->5,indexers->[index],dc->[])
# /kr/26                              frame_table  (typ->appendable,nrows->2903,ncols->5,indexers->[index],dc->[])
# /kr/260                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/261                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/262                             frame_table  (typ->appendable,nrows->7507,ncols->5,indexers->[index],dc->[])
# /kr/263                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/264                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/265                             frame_table  (typ->appendable,nrows->3015,ncols->5,indexers->[index],dc->[])
# /kr/266                             frame_table  (typ->appendable,nrows->7134,ncols->5,indexers->[index],dc->[])
# /kr/267                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/268                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/269                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/27                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/270                             frame_table  (typ->appendable,nrows->3487,ncols->5,indexers->[index],dc->[])
# /kr/271                             frame_table  (typ->appendable,nrows->7524,ncols->5,indexers->[index],dc->[])
# /kr/272                             frame_table  (typ->appendable,nrows->2230,ncols->5,indexers->[index],dc->[])
# /kr/273                             frame_table  (typ->appendable,nrows->4749,ncols->5,indexers->[index],dc->[])
# /kr/274                             frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/275                             frame_table  (typ->appendable,nrows->1875,ncols->5,indexers->[index],dc->[])
# ...
# /kr/893                             frame_table  (typ->appendable,nrows->4946,ncols->5,indexers->[index],dc->[])
# /kr/894                             frame_table  (typ->appendable,nrows->2078,ncols->5,indexers->[index],dc->[])
# /kr/895                             frame_table  (typ->appendable,nrows->3366,ncols->5,indexers->[index],dc->[])
# /kr/896                             frame_table  (typ->appendable,nrows->5069,ncols->5,indexers->[index],dc->[])
# /kr/897                             frame_table  (typ->appendable,nrows->5009,ncols->5,indexers->[index],dc->[])
# /kr/898                             frame_table  (typ->appendable,nrows->5009,ncols->5,indexers->[index],dc->[])
# /kr/899                             frame_table  (typ->appendable,nrows->2868,ncols->5,indexers->[index],dc->[])
# /kr/9                               frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/90                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/900                             frame_table  (typ->appendable,nrows->3079,ncols->5,indexers->[index],dc->[])
# /kr/901                             frame_table  (typ->appendable,nrows->2502,ncols->5,indexers->[index],dc->[])
# /kr/902                             frame_table  (typ->appendable,nrows->2991,ncols->5,indexers->[index],dc->[])
# /kr/903                             frame_table  (typ->appendable,nrows->921,ncols->5,indexers->[index],dc->[])
# /kr/904                             frame_table  (typ->appendable,nrows->4915,ncols->5,indexers->[index],dc->[])
# /kr/905                             frame_table  (typ->appendable,nrows->2681,ncols->5,indexers->[index],dc->[])
# /kr/906                             frame_table  (typ->appendable,nrows->4688,ncols->5,indexers->[index],dc->[])
# /kr/907                             frame_table  (typ->appendable,nrows->4944,ncols->5,indexers->[index],dc->[])
# /kr/908                             frame_table  (typ->appendable,nrows->4205,ncols->5,indexers->[index],dc->[])
# /kr/909                             frame_table  (typ->appendable,nrows->2678,ncols->5,indexers->[index],dc->[])
# /kr/91                              frame_table  (typ->appendable,nrows->6046,ncols->5,indexers->[index],dc->[])
# /kr/910                             frame_table  (typ->appendable,nrows->2615,ncols->5,indexers->[index],dc->[])
# /kr/911                             frame_table  (typ->appendable,nrows->1708,ncols->5,indexers->[index],dc->[])
# /kr/912                             frame_table  (typ->appendable,nrows->2762,ncols->5,indexers->[index],dc->[])
# /kr/913                             frame_table  (typ->appendable,nrows->4852,ncols->5,indexers->[index],dc->[])
# /kr/914                             frame_table  (typ->appendable,nrows->897,ncols->5,indexers->[index],dc->[])
# /kr/915                             frame_table  (typ->appendable,nrows->1130,ncols->5,indexers->[index],dc->[])
# /kr/916                             frame_table  (typ->appendable,nrows->1905,ncols->5,indexers->[index],dc->[])
# /kr/917                             frame_table  (typ->appendable,nrows->2625,ncols->5,indexers->[index],dc->[])
# /kr/918                             frame_table  (typ->appendable,nrows->4795,ncols->5,indexers->[index],dc->[])
# /kr/919                             frame_table  (typ->appendable,nrows->4766,ncols->5,indexers->[index],dc->[])
# /kr/92                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/920                             frame_table  (typ->appendable,nrows->2604,ncols->5,indexers->[index],dc->[])
# /kr/921                             frame_table  (typ->appendable,nrows->4703,ncols->5,indexers->[index],dc->[])
# /kr/922                             frame_table  (typ->appendable,nrows->3965,ncols->5,indexers->[index],dc->[])
# /kr/923                             frame_table  (typ->appendable,nrows->4696,ncols->5,indexers->[index],dc->[])
# /kr/924                             frame_table  (typ->appendable,nrows->2215,ncols->5,indexers->[index],dc->[])
# /kr/925                             frame_table  (typ->appendable,nrows->3577,ncols->5,indexers->[index],dc->[])
# /kr/926                             frame_table  (typ->appendable,nrows->4654,ncols->5,indexers->[index],dc->[])
# /kr/927                             frame_table  (typ->appendable,nrows->4629,ncols->5,indexers->[index],dc->[])
# /kr/928                             frame_table  (typ->appendable,nrows->1856,ncols->5,indexers->[index],dc->[])
# /kr/929                             frame_table  (typ->appendable,nrows->4635,ncols->5,indexers->[index],dc->[])
# /kr/93                              frame_table  (typ->appendable,nrows->2570,ncols->5,indexers->[index],dc->[])
# /kr/930                             frame_table  (typ->appendable,nrows->2491,ncols->5,indexers->[index],dc->[])
# /kr/931                             frame_table  (typ->appendable,nrows->4577,ncols->5,indexers->[index],dc->[])
# /kr/932                             frame_table  (typ->appendable,nrows->4619,ncols->5,indexers->[index],dc->[])
# /kr/933                             frame_table  (typ->appendable,nrows->1271,ncols->5,indexers->[index],dc->[])
# /kr/934                             frame_table  (typ->appendable,nrows->4459,ncols->5,indexers->[index],dc->[])
# /kr/935                             frame_table  (typ->appendable,nrows->4564,ncols->5,indexers->[index],dc->[])
# /kr/936                             frame_table  (typ->appendable,nrows->2837,ncols->5,indexers->[index],dc->[])
# /kr/937                             frame_table  (typ->appendable,nrows->2485,ncols->5,indexers->[index],dc->[])
# /kr/938                             frame_table  (typ->appendable,nrows->3953,ncols->5,indexers->[index],dc->[])
# /kr/939                             frame_table  (typ->appendable,nrows->3018,ncols->5,indexers->[index],dc->[])
# /kr/94                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/940                             frame_table  (typ->appendable,nrows->4472,ncols->5,indexers->[index],dc->[])
# /kr/941                             frame_table  (typ->appendable,nrows->4452,ncols->5,indexers->[index],dc->[])
# /kr/942                             frame_table  (typ->appendable,nrows->4069,ncols->5,indexers->[index],dc->[])
# /kr/943                             frame_table  (typ->appendable,nrows->4353,ncols->5,indexers->[index],dc->[])
# /kr/944                             frame_table  (typ->appendable,nrows->3900,ncols->5,indexers->[index],dc->[])
# /kr/945                             frame_table  (typ->appendable,nrows->1390,ncols->5,indexers->[index],dc->[])
# /kr/946                             frame_table  (typ->appendable,nrows->1305,ncols->5,indexers->[index],dc->[])
# /kr/947                             frame_table  (typ->appendable,nrows->4202,ncols->5,indexers->[index],dc->[])
# /kr/948                             frame_table  (typ->appendable,nrows->4264,ncols->5,indexers->[index],dc->[])
# /kr/949                             frame_table  (typ->appendable,nrows->4214,ncols->5,indexers->[index],dc->[])
# /kr/95                              frame_table  (typ->appendable,nrows->4824,ncols->5,indexers->[index],dc->[])
# /kr/950                             frame_table  (typ->appendable,nrows->4075,ncols->5,indexers->[index],dc->[])
# /kr/951                             frame_table  (typ->appendable,nrows->4202,ncols->5,indexers->[index],dc->[])
# /kr/952                             frame_table  (typ->appendable,nrows->4104,ncols->5,indexers->[index],dc->[])
# /kr/953                             frame_table  (typ->appendable,nrows->3878,ncols->5,indexers->[index],dc->[])
# /kr/954                             frame_table  (typ->appendable,nrows->676,ncols->5,indexers->[index],dc->[])
# /kr/955                             frame_table  (typ->appendable,nrows->1430,ncols->5,indexers->[index],dc->[])
# /kr/956                             frame_table  (typ->appendable,nrows->3652,ncols->5,indexers->[index],dc->[])
# /kr/957                             frame_table  (typ->appendable,nrows->2321,ncols->5,indexers->[index],dc->[])
# /kr/958                             frame_table  (typ->appendable,nrows->4106,ncols->5,indexers->[index],dc->[])
# /kr/959                             frame_table  (typ->appendable,nrows->2673,ncols->5,indexers->[index],dc->[])
# /kr/96                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/960                             frame_table  (typ->appendable,nrows->2915,ncols->5,indexers->[index],dc->[])
# /kr/961                             frame_table  (typ->appendable,nrows->2604,ncols->5,indexers->[index],dc->[])
# /kr/962                             frame_table  (typ->appendable,nrows->3901,ncols->5,indexers->[index],dc->[])
# /kr/963                             frame_table  (typ->appendable,nrows->3894,ncols->5,indexers->[index],dc->[])
# /kr/964                             frame_table  (typ->appendable,nrows->3961,ncols->5,indexers->[index],dc->[])
# /kr/965                             frame_table  (typ->appendable,nrows->3960,ncols->5,indexers->[index],dc->[])
# /kr/966                             frame_table  (typ->appendable,nrows->3945,ncols->5,indexers->[index],dc->[])
# /kr/967                             frame_table  (typ->appendable,nrows->3859,ncols->5,indexers->[index],dc->[])
# /kr/968                             frame_table  (typ->appendable,nrows->3341,ncols->5,indexers->[index],dc->[])
# /kr/969                             frame_table  (typ->appendable,nrows->1656,ncols->5,indexers->[index],dc->[])
# /kr/97                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/970                             frame_table  (typ->appendable,nrows->3854,ncols->5,indexers->[index],dc->[])
# /kr/971                             frame_table  (typ->appendable,nrows->3864,ncols->5,indexers->[index],dc->[])
# /kr/972                             frame_table  (typ->appendable,nrows->2806,ncols->5,indexers->[index],dc->[])
# /kr/973                             frame_table  (typ->appendable,nrows->3791,ncols->5,indexers->[index],dc->[])
# /kr/974                             frame_table  (typ->appendable,nrows->3668,ncols->5,indexers->[index],dc->[])
# /kr/975                             frame_table  (typ->appendable,nrows->1656,ncols->5,indexers->[index],dc->[])
# /kr/976                             frame_table  (typ->appendable,nrows->3746,ncols->5,indexers->[index],dc->[])
# /kr/977                             frame_table  (typ->appendable,nrows->3726,ncols->5,indexers->[index],dc->[])
# /kr/978                             frame_table  (typ->appendable,nrows->3606,ncols->5,indexers->[index],dc->[])
# /kr/979                             frame_table  (typ->appendable,nrows->3728,ncols->5,indexers->[index],dc->[])
# /kr/98                              frame_table  (typ->appendable,nrows->2766,ncols->5,indexers->[index],dc->[])
# /kr/980                             frame_table  (typ->appendable,nrows->3707,ncols->5,indexers->[index],dc->[])
# /kr/981                             frame_table  (typ->appendable,nrows->736,ncols->5,indexers->[index],dc->[])
# /kr/982                             frame_table  (typ->appendable,nrows->3407,ncols->5,indexers->[index],dc->[])
# /kr/983                             frame_table  (typ->appendable,nrows->3656,ncols->5,indexers->[index],dc->[])
# /kr/984                             frame_table  (typ->appendable,nrows->3658,ncols->5,indexers->[index],dc->[])
# /kr/985                             frame_table  (typ->appendable,nrows->3399,ncols->5,indexers->[index],dc->[])
# /kr/986                             frame_table  (typ->appendable,nrows->893,ncols->5,indexers->[index],dc->[])
# /kr/987                             frame_table  (typ->appendable,nrows->3622,ncols->5,indexers->[index],dc->[])
# /kr/988                             frame_table  (typ->appendable,nrows->3397,ncols->5,indexers->[index],dc->[])
# /kr/989                             frame_table  (typ->appendable,nrows->2922,ncols->5,indexers->[index],dc->[])
# /kr/99                              frame_table  (typ->appendable,nrows->7776,ncols->5,indexers->[index],dc->[])
# /kr/990                             frame_table  (typ->appendable,nrows->3607,ncols->5,indexers->[index],dc->[])
# /kr/991                             frame_table  (typ->appendable,nrows->3402,ncols->5,indexers->[index],dc->[])
# /kr/992                             frame_table  (typ->appendable,nrows->1458,ncols->5,indexers->[index],dc->[])
# /kr/993                             frame_table  (typ->appendable,nrows->3500,ncols->5,indexers->[index],dc->[])
# /kr/994                             frame_table  (typ->appendable,nrows->3459,ncols->5,indexers->[index],dc->[])
# /kr/995                             frame_table  (typ->appendable,nrows->3463,ncols->5,indexers->[index],dc->[])
# /kr/996                             frame_table  (typ->appendable,nrows->3437,ncols->5,indexers->[index],dc->[])
# /kr/997                             frame_table  (typ->appendable,nrows->2217,ncols->5,indexers->[index],dc->[])
# /kr/998                             frame_table  (typ->appendable,nrows->3420,ncols->5,indexers->[index],dc->[])
# /kr/999                             frame_table  (typ->appendable,nrows->3237,ncols->5,indexers->[index],dc->[])
# /kr/equities                        frame_table  (typ->appendable,nrows->1162,ncols->3,indexers->[index],dc->[])
# /kr/splits                          frame_table  (typ->appendable,nrows->1,ncols->3,indexers->[index],dc->[])

# %% [markdown]
# ## Zipline Root 폴더 찾기
# - 컴퓨터마다 다르지만 제 컴퓨터에서는 C:\Users\PC\.zipline 이었다.

# %% [markdown]
# 파일 이동
# ./zipline에 있는 데이터 들을 복사해서 백업해둔다.
# 여기 폴더에 있는 fnguide_kr_stocks.py와 extension.py을 이동한다. custom_data라는 폴더를 만든다.
# fnguide.h5 데이터를 custom_data 폴더 안으로 넣는다.

# %% [markdown]
# ## 최종 구조
# .zipline 폴더 위치
#
#
#     |-extension.py
#     |-fnguide_kr_stocks.py
#     |-custom_data
#         |-fnguide.h5

# %%
with pd.HDFStore('fnguide.h5') as store:
    stocks = store['kr/equities']

# %%
stocks.head(50)
# Out:
#     sid  ticker      name
# 0     0  000010      조흥은행
# 1     1  000020      동화약품
# 2     2  000030      우리은행
# 3     3  000040     KR모터스
# 4     4  000050        경방
# 5     5  000060     메리츠화재
# 6     6  000070     삼양홀딩스
# 7     7  000080     하이트진로
# 8     8  000090      두산상사
# 9     9  000100      유한양행
# 10   10  000110      제일은행
# 11   11  000120    CJ대한통운
# 12   12  000130      한일은행
# 13   13  000140  하이트진로홀딩스
# 14   14  000150        두산
# 15   15  000160      대한중석
# 16   16  000170      LG금속
# 17   17  000180    성창기업지주
# 18   18  000200     대우중공업
# 19   19  000210        DL
# 20   20  000220      유유제약
# 21   21  000230     일동홀딩스
# 22   22  000240    한국앤컴퍼니
# 23   23  000270        기아
# 24   24  000280      동아건설
# 25   25  000300     대유플러스
# 26   26  000310      해태제과
# 27   27  000320     노루홀딩스
# 28   28  000330      두산백화
# 29   29  000360      삼환기업
# 30   30  000370    한화손해보험
# 31   31  000390     삼화페인트
# 32   32  000400    롯데손해보험
# 33   33  000420     로케트전기
# 34   34  000430      대원강업
# 35   35  000450      한주통산
# 36   36  000470    그린손해보험
# 37   37  000480      조선내화
# 38   38  000490        대동
# 39   39  000500      가온전선
# 40   40  000510        태화
# 41   41  000520      삼일제약
# 42   42  000540      흥국화재
# 43   43  000570      금호건설
# 44   44  000590     CS홀딩스
# 45   45  000600      삼화실업
# 46   46  000610      제일화재
# 47   47  000640  동아쏘시오홀딩스
# 48   48  000650      천일고속
# 49   49  000660    SK하이닉스
