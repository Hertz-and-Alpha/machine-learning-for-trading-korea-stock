# %% [markdown]
# # Zipline Custome Bundle 생성
# 기존에 Zipline Bundle은 미국주식으로만 되어 있었다. 국내주식을 이용하시 위해서 한국주식으로 되어 있는 custom bundle을 생성해서 사용해보도록 하자

# %% [markdown]
# ## Imports & Settings

# %%
from pathlib import Path 
import warnings
import pandas as pd 

warnings.filterwarnings('ignore')

DATA_DIR = Path('..', '..', 'data')
idx = pd.IndexSlice

# %%
def create_split_table():
    with pd.HDFStore('finance_datareader.h5') as store:
        store.put('kr/splits', pd.DataFrame(columns=['sid', 'effective_date', 'ratio'],
                                            data=[[1, pd.to_datetime('2000-01-01'), 1.0]]), format='t')

def load_prices():
    df = pd.read_hdf(DATA_DIR / 'assets.h5', 'finance_datareader/prices')

    return (df.loc[idx['2010': '2020', :], :]
            .reindex(columns=['adj_open', 'adj_high', 'adj_low', 'adj_close', 'adj_volume'])
            .rename(columns=lambda x: x.replace('adj_', ''))
            .unstack('ticker')
            .sort_index()
            .tz_localize('UTC')
#             .ffill(limit=5)
            .fillna(method='bfill')
            .fillna(0.01)
            .dropna(axis=1)
            .stack('ticker')
            .swaplevel()
           )

def load_symbols(tickers):
    df = pd.read_hdf(DATA_DIR / 'assets.h5', 'finance_datareader/stocks')
    df.index.names = ['ticker']
    df.reset_index(inplace=True)
    return (df[df.ticker.isin(tickers)]
            .reset_index(drop=True)
            .reset_index()
            .rename(columns={'index': 'sid'}))

# %%
prices = load_prices()

# %%
prices
# Out:
#                                     close          high           low  \
# ticker date
# 000020 2010-01-04 00:00:00+00:00   7520.0   7820.000000   7480.000000
# 000040 2010-01-04 00:00:00+00:00   3635.0   3726.638655   3421.176471
# 000050 2010-01-04 00:00:00+00:00   9921.0  10187.080460   9768.954023
# 000060 2010-01-04 00:00:00+00:00   8696.0   8696.000000   8297.433333
# 000070 2010-01-04 00:00:00+00:00  46517.0  46517.000000  45790.171875
# ...                                   ...           ...           ...
# 357120 2020-12-30 00:00:00+00:00   4805.0   4810.000000   4780.000000
# 357250 2020-12-30 00:00:00+00:00   4755.0   4765.000000   4720.000000
# 363280 2020-12-30 00:00:00+00:00  27700.0  28250.000000  25950.000000
# 365550 2020-12-30 00:00:00+00:00   5070.0   5090.000000   5040.000000
# 900140 2020-12-30 00:00:00+00:00   3850.0   3920.000000   3790.000000
#
#                                           open        volume
# ticker date
# 000020 2010-01-04 00:00:00+00:00   7540.000000  1.771970e+05
# 000040 2010-01-04 00:00:00+00:00   3421.176471  1.839257e+05
# 000050 2010-01-04 00:00:00+00:00   9882.988506  9.483973e+03
# 000060 2010-01-04 00:00:00+00:00   8333.666667  1.110800e+06
# 000070 2010-01-04 00:00:00+00:00  46309.334821  1.289576e+04
# ...                                        ...           ...
# 357120 2020-12-30 00:00:00+00:00   4810.000000  1.236580e+05
# 357250 2020-12-30 00:00:00+00:00   4765.000000  5.417800e+04
# 363280 2020-12-30 00:00:00+00:00  26300.000000  8.664610e+05
# 365550 2020-12-30 00:00:00+00:00   5080.000000  4.104520e+05
# 900140 2020-12-30 00:00:00+00:00   3830.000000  1.001111e+06
#
# [2154916 rows x 5 columns]

# %%
print(prices.info(null_counts=True))
tickers = prices.index.unique('ticker')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2154916 entries, ('000020', Timestamp('2010-01-04 00:00:00+0000', tz='UTC')) to ('900140', Timestamp('2020-12-30 00:00:00+0000', tz='UTC'))
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   close   2154916 non-null  float64
#  1   high    2154916 non-null  float64
#  2   low     2154916 non-null  float64
#  3   open    2154916 non-null  float64
#  4   volume  2154916 non-null  float64
# dtypes: float64(5)
# memory usage: 90.5+ MB
# None

# %%
symbols = load_symbols(tickers)
print(symbols.info(null_counts=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sid     783 non-null    int64
#  1   ticker  783 non-null    object
#  2   name    783 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 18.5+ KB
# None

# %%
# ticker 저장
symbols.to_hdf('finance_datareader.h5', 'kr/equities', format='t')

# %%
dates = prices.index.unique('date')
start_date = dates.min()
end_date = dates.max()

# %%
for sid, symbol in symbols.set_index('sid').ticker.items():
        p = prices.loc[symbol]
        p.to_hdf('finance_datareader.h5', 'kr/{}'.format(sid), format='t')

with pd.HDFStore('finance_datareader.h5') as store:
        print(store.info())

create_split_table()
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: finance_datareader.h5
# /kr/0                   frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/1                   frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/10                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/100                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/101                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/102                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/103                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/104                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/105                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/106                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/107                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/108                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/109                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/11                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/110                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/111                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/112                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/113                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/114                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/115                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/116                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/117                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/118                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/119                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/12                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/120                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/121                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/122                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/123                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/124                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/125                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/126                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/127                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/128                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/129                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/13                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/130                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/131                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/132                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/133                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/134                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/135                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/136                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/137                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/138                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/139                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/14                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/140                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/141                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/142                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/143                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/144                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/145                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/146                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/147                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/148                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/149                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/15                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/150                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/151                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/152                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/153                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/154                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/155                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/156                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/157                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/158                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/159                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/16                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/160                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/161                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/162                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/163                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/164                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/165                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/166                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/167                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/168                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/169                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/17                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/170                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/171                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/172                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/173                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/174                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/175                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/176                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/177                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/178                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/179                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/18                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/180                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/181                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/182                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/183                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/184                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/185                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/186                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/187                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/188                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/189                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/19                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/190                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/191                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/192                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/193                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/194                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/195                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/196                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/197                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/198                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/199                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/2                   frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/20                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/200                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/201                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/202                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/203                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/204                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/205                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/206                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/207                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/208                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/209                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/21                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/210                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/211                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/212                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/213                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/214                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/215                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/216                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/217                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/218                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/219                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/22                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/220                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/221                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/222                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/223                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/224                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/225                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/226                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/227                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/228                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/229                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/23                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/230                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/231                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/232                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/233                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/234                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/235                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/236                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/237                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/238                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/239                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/24                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/240                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/241                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/242                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/243                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/244                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/245                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/246                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/247                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/248                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/249                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/25                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/250                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/251                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/252                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/253                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/254                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/255                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/256                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/257                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/258                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/259                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/26                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/260                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/261                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/262                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/263                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/264                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/265                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/266                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/267                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/268                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/269                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/27                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/270                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/271                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/272                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/273                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/274                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/275                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/276                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/277                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/278                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/279                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/28                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/280                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/281                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/282                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/283                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/284                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/285                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/286                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/287                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/288                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/289                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/29                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/290                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/291                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/292                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/293                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/294                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/295                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/296                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/297                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/298                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/299                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/3                   frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/30                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/300                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/301                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/302                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/303                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/304                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/305                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/306                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/307                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/308                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/309                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/31                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/310                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/311                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/312                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/313                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/314                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/315                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/316                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/317                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/318                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/319                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/32                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/320                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/321                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/322                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/323                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/324                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/325                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/326                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/327                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/328                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/329                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/33                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/330                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/331                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/332                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/333                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/334                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/335                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/336                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/337                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/338                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/339                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/34                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/340                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/341                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/342                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/343                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/344                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/345                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/346                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/347                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/348                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/349                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/35                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/350                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/351                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/352                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/353                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/354                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/355                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/356                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/357                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/358                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/359                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/36                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/360                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/361                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/362                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/363                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/364                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/365                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/366                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/367                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/368                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/369                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/37                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/370                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/371                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/372                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/373                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/374                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/375                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/376                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/377                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/378                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/379                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/38                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/380                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/381                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/382                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/383                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/384                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/385                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/386                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/387                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/388                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/389                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/39                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/390                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/391                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/392                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/393                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/394                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/395                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/396                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/397                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/398                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/399                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/4                   frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/40                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/400                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/401                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/402                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/403                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/404                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/405                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/406                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/407                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/408                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/409                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/41                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/410                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/411                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/412                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/413                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/414                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/415                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/416                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/417                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/418                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/419                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/42                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/420                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/421                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/422                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/423                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/424                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/425                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/426                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/427                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/428                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/429                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/43                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/430                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/431                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/432                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/433                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/434                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/435                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/436                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/437                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/438                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/439                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/44                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/440                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/441                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/442                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/443                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/444                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/445                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/446                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/447                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/448                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/449                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/45                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/450                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/451                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/452                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/453                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/454                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/455                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/456                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/457                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/458                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/459                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/46                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/460                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/461                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/462                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/463                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/464                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/465                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/466                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/467                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/468                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/469                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/47                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/470                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/471                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/472                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/473                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/474                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/475                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/476                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/477                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/478                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/479                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/48                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/480                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/481                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/482                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/483                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/484                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/485                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/486                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/487                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/488                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/489                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/49                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/490                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/491                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/492                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/493                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/494                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/495                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/496                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/497                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/498                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/499                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/5                   frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/50                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/500                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/501                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/502                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/503                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/504                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/505                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/506                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/507                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/508                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/509                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/51                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/510                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/511                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/512                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/513                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/514                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/515                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/516                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/517                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/518                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/519                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/52                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/520                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/521                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/522                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/523                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/524                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# ...
# /kr/670                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/671                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/672                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/673                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/674                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/675                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/676                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/677                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/678                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/679                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/68                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/680                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/681                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/682                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/683                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/684                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/685                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/686                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/687                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/688                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/689                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/69                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/690                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/691                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/692                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/693                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/694                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/695                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/696                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/697                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/698                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/699                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/7                   frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/70                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/700                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/701                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/702                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/703                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/704                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/705                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/706                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/707                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/708                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/709                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/71                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/710                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/711                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/712                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/713                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/714                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/715                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/716                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/717                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/718                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/719                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/72                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/720                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/721                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/722                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/723                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/724                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/725                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/726                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/727                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/728                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/729                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/73                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/730                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/731                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/732                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/733                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/734                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/735                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/736                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/737                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/738                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/739                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/74                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/740                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/741                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/742                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/743                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/744                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/745                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/746                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/747                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/748                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/749                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/75                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/750                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/751                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/752                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/753                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/754                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/755                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/756                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/757                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/758                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/759                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/76                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/760                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/761                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/762                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/763                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/764                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/765                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/766                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/767                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/768                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/769                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/77                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/770                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/771                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/772                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/773                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/774                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/775                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/776                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/777                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/778                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/779                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/78                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/780                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/781                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/782                 frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/783                 frame_table  (typ->appendable,nrows->2809,ncols->5,indexers->[index],dc->[])
# /kr/784                 frame_table  (typ->appendable,nrows->2809,ncols->5,indexers->[index],dc->[])
# /kr/785                 frame_table  (typ->appendable,nrows->2809,ncols->5,indexers->[index],dc->[])
# /kr/786                 frame_table  (typ->appendable,nrows->2809,ncols->5,indexers->[index],dc->[])
# /kr/787                 frame_table  (typ->appendable,nrows->2809,ncols->5,indexers->[index],dc->[])
# /kr/788                 frame_table  (typ->appendable,nrows->2809,ncols->5,indexers->[index],dc->[])
# /kr/789                 frame_table  (typ->appendable,nrows->2809,ncols->5,indexers->[index],dc->[])
# /kr/79                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/790                 frame_table  (typ->appendable,nrows->2809,ncols->5,indexers->[index],dc->[])
# /kr/8                   frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/80                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/81                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/82                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/83                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/84                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/85                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/86                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/87                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/88                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/89                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/9                   frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/90                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/91                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/92                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/93                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/94                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/95                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/96                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/97                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/98                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/99                  frame_table  (typ->appendable,nrows->2714,ncols->5,indexers->[index],dc->[])
# /kr/equities            frame_table  (typ->appendable,nrows->783,ncols->3,indexers->[index],dc->[])
# /kr/splits              frame_table  (typ->appendable,nrows->1,ncols->3,indexers->[index],dc->[])

# %%
prices.index.get_level_values('ticker').unique()
# Out:
# Index(['000020', '000040', '000050', '000060', '000070', '000100', '000120',
#        '000140', '000150', '000180',
#        ...
#        '344820', '348950', '350520', '352820', '353200', '357120', '357250',
#        '363280', '365550', '900140'],
#       dtype='object', name='ticker', length=794)

# %% [markdown]
# ## 설정법
# 1. finance_datareader.h5가 잘 설정되었는지 확인한다.

# %% [markdown]
# ## Zipline Root 폴더 찾기
# - 컴퓨터마다 다르지만 제 컴퓨터에서는 C:\Users\PC\.zipline 이었다.

# %% [markdown]
# 파일 이동
# 1. ./zipline에 있는 데이터 들을 복사해서 백업해둔다.
# 2. 여기 폴더에 있는 finance_datareader_kr_stocks.py와 extension.py을 이동한다.
# custom_data라는 폴더를 만든다.
# 3. finance_datareader.h5 데이터를 custom_data 폴더 안으로 넣는다.

# %% [markdown]
# ## 최종 구조
# .zipline 폴더 위치
#
#
#     |-extension.py
#     |-finance_datareader_kr_stocks.py
#     |-custom_data
#         |-finance_datareader.h5
