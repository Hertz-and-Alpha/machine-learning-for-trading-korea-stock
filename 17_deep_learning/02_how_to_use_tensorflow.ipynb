# %% [markdown]
# # How to use Tensorflow 2

# %% [markdown]
# Keras was designed as a high-level or meta API to accelerate the iterative workflow when designing and training deep neural networks with computational backends like TensorFlow, Theano, or CNTK. It has been integrated into TensorFlow in 2017 and is set to become the principal TensorFlow interface with the 2.0 release. You can also combine code from both libraries to leverage Keras’ high-level abstractions as well as customized TensorFlow graph operations.

# %% [markdown]
# Please follow the installations instructions in `Installation Guide.md` in the root folder.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path
from copy import deepcopy
import numpy as np
import pandas as pd

import sklearn
from sklearn.datasets import make_circles # To generate the dataset

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import TensorBoard

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.mplot3d import Axes3D  # 3D plots

import seaborn as sns
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
# plotting style
sns.set_style('white')
# for reproducibility
np.random.seed(seed=42)

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using GPU

# %%
results_path = Path('results')
if not results_path.exists():
    results_path.mkdir()

# %% [markdown]
# ## Input Data

# %% [markdown]
# ### Generate random data

# %% [markdown]
# The target `y` represents two classes generated by two circular distribution that are not linearly separable because class 0 surrounds class 1.

# %%
# dataset params
N = 50000
factor = 0.1
noise = 0.1

# %%
# generate data
X, y = make_circles(
    n_samples=N,
    shuffle=True,
    factor=factor,
    noise=noise)

# %%
# define outcome matrix
Y = np.zeros((N, 2))
for c in [0, 1]:
    Y[y == c, c] = 1

# %%
f'Shape of: X: {X.shape} | Y: {Y.shape} | y: {y.shape}'
# Out:
# 'Shape of: X: (50000, 2) | Y: (50000, 2) | y: (50000,)'

# %% [markdown]
# ### Visualize Data

# %%
sns.scatterplot(x=X[:, 0], 
                y=X[:, 1], 
                hue=y,
               style=y,
               markers=['_', '+']);

# %% [markdown]
# ## Build Keras Model

# %% [markdown]
# Keras supports both a slightly simpler Sequential and more flexible Functional API. We will introduce the former at this point and use the Functional API in more complex examples in the following chapters.
#
# To create a model, we just need to instantiate a Sequential object and provide a list with the sequence of standard layers and their configurations, including the number of units, type of activation function, or name.

# %% [markdown]
# ### Define Architecture

# %%
model = Sequential([
    Dense(units=3, input_shape=(2,), name='hidden'),
    Activation('sigmoid', name='logistic'),
    Dense(2, name='output'),
    Activation('softmax', name='softmax'),
])

# %% [markdown]
# The first hidden layer needs information about the number of features in the matrix it receives from the input layer via the input_shape argument. In our simple case, these are just two. Keras infers the number of rows it needs to process during training, through the batch_size argument that we will pass to the fit method below.
#
# Keras infers the sizes of the inputs received by other layers from the previous layer’s units argument.

# %% [markdown]
# Keras provides numerous standard building blocks, including recurrent and convolutional layers, various options for regularization, a range of loss functions and optimizers, and also preprocessing, visualization and logging (see documentation on GitHub for reference). It is also extensible.
#
# The model’s summary method produces a concise description of the network architecture, including a list of the layer types and shapes, and the number of parameters:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden (Dense)               (None, 3)                 9
# _________________________________________________________________
# logistic (Activation)        (None, 3)                 0
# _________________________________________________________________
# output (Dense)               (None, 2)                 8
# _________________________________________________________________
# softmax (Activation)         (None, 2)                 0
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile Model

# %% [markdown]
# Next, we compile the Sequential model to configure the learning process. To this end, we define the optimizer, the loss function, and one or several performance metrics to monitor during training:

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Tensorboard Callback

# %% [markdown]
# Keras uses callbacks to enable certain functionality during training, such as logging information for interactive display in TensorBoard (see next section):

# %%
tb_callback = TensorBoard(log_dir=results_path / 'tensorboard', 
                          histogram_freq=1, 
                          write_graph=True, 
                          write_images=True)

# %% [markdown]
# ## Train Model

# %% [markdown]
# To train the model, we call its fit method and pass several parameters in addition to the training data:

# %%
training=model.fit(X, 
          Y, 
          epochs=50,
          validation_split=.2,
          batch_size=128, 
          verbose=1, 
          callbacks=[tb_callback])
# Out:
# Epoch 1/50
# 313/313 [==============================] - 4s 3ms/step - loss: 0.8012 - accuracy: 0.5030 - val_loss: 0.7101 - val_accuracy: 0.4925
# Epoch 2/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7006 - accuracy: 0.5055 - val_loss: 0.6934 - val_accuracy: 0.6885
# Epoch 3/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6933 - accuracy: 0.5629 - val_loss: 0.6932 - val_accuracy: 0.4058
# Epoch 4/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6932 - accuracy: 0.4993 - val_loss: 0.6933 - val_accuracy: 0.6719
# Epoch 5/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6932 - accuracy: 0.5464 - val_loss: 0.6933 - val_accuracy: 0.5382
# Epoch 6/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6931 - accuracy: 0.6175 - val_loss: 0.6931 - val_accuracy: 0.6495
# Epoch 7/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6929 - accuracy: 0.5300 - val_loss: 0.6928 - val_accuracy: 0.4604
# Epoch 8/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6927 - accuracy: 0.4217 - val_loss: 0.6925 - val_accuracy: 0.5855
# Epoch 9/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6918 - accuracy: 0.6783 - val_loss: 0.6905 - val_accuracy: 0.7263
# Epoch 10/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6893 - accuracy: 0.7300 - val_loss: 0.6862 - val_accuracy: 0.7544
# Epoch 11/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6839 - accuracy: 0.7614 - val_loss: 0.6780 - val_accuracy: 0.7790
# Epoch 12/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6749 - accuracy: 0.7860 - val_loss: 0.6650 - val_accuracy: 0.7977
# Epoch 13/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6602 - accuracy: 0.8085 - val_loss: 0.6475 - val_accuracy: 0.8157
# Epoch 14/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6415 - accuracy: 0.8233 - val_loss: 0.6249 - val_accuracy: 0.8284
# Epoch 15/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6171 - accuracy: 0.8357 - val_loss: 0.5962 - val_accuracy: 0.8392
# Epoch 16/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5875 - accuracy: 0.8441 - val_loss: 0.5624 - val_accuracy: 0.8467
# Epoch 17/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.8536 - val_loss: 0.5245 - val_accuracy: 0.8582
# Epoch 18/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5149 - accuracy: 0.8625 - val_loss: 0.4848 - val_accuracy: 0.8693
# Epoch 19/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4737 - accuracy: 0.8772 - val_loss: 0.4451 - val_accuracy: 0.8917
# Epoch 20/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4347 - accuracy: 0.8977 - val_loss: 0.4056 - val_accuracy: 0.9203
# Epoch 21/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3956 - accuracy: 0.9230 - val_loss: 0.3667 - val_accuracy: 0.9383
# Epoch 22/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3567 - accuracy: 0.9433 - val_loss: 0.3295 - val_accuracy: 0.9600
# Epoch 23/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3208 - accuracy: 0.9659 - val_loss: 0.2936 - val_accuracy: 0.9822
# Epoch 24/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2857 - accuracy: 0.9874 - val_loss: 0.2600 - val_accuracy: 0.9952
# Epoch 25/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2516 - accuracy: 0.9965 - val_loss: 0.2289 - val_accuracy: 0.9989
# Epoch 26/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2228 - accuracy: 0.9994 - val_loss: 0.2010 - val_accuracy: 0.9995
# Epoch 27/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1942 - accuracy: 0.9995 - val_loss: 0.1756 - val_accuracy: 0.9997
# Epoch 28/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1703 - accuracy: 0.9997 - val_loss: 0.1529 - val_accuracy: 0.9997
# Epoch 29/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1477 - accuracy: 0.9999 - val_loss: 0.1326 - val_accuracy: 0.9997
# Epoch 30/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1279 - accuracy: 0.9999 - val_loss: 0.1150 - val_accuracy: 0.9997
# Epoch 31/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1111 - accuracy: 0.9998 - val_loss: 0.0996 - val_accuracy: 0.9997
# Epoch 32/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0962 - accuracy: 0.9999 - val_loss: 0.0862 - val_accuracy: 0.9997
# Epoch 33/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0833 - accuracy: 0.9997 - val_loss: 0.0744 - val_accuracy: 0.9997
# Epoch 34/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0718 - accuracy: 0.9999 - val_loss: 0.0642 - val_accuracy: 0.9997
# Epoch 35/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0621 - accuracy: 0.9999 - val_loss: 0.0555 - val_accuracy: 0.9998
# Epoch 36/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 0.9998
# Epoch 37/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0460 - accuracy: 0.9999 - val_loss: 0.0414 - val_accuracy: 0.9998
# Epoch 38/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0395 - accuracy: 0.9999 - val_loss: 0.0358 - val_accuracy: 0.9998
# Epoch 39/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0344 - accuracy: 0.9999 - val_loss: 0.0310 - val_accuracy: 0.9998
# Epoch 40/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0296 - accuracy: 0.9999 - val_loss: 0.0270 - val_accuracy: 0.9998
# Epoch 41/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0257 - accuracy: 0.9999 - val_loss: 0.0235 - val_accuracy: 0.9998
# Epoch 42/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0226 - accuracy: 0.9999 - val_loss: 0.0204 - val_accuracy: 0.9998
# Epoch 43/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0194 - accuracy: 0.9999 - val_loss: 0.0178 - val_accuracy: 0.9998
# Epoch 44/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0169 - accuracy: 0.9999 - val_loss: 0.0156 - val_accuracy: 0.9997
# Epoch 45/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0148 - accuracy: 0.9999 - val_loss: 0.0137 - val_accuracy: 0.9997
# Epoch 46/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0130 - accuracy: 0.9999 - val_loss: 0.0120 - val_accuracy: 0.9997
# Epoch 47/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.9999 - val_loss: 0.0106 - val_accuracy: 0.9997
# Epoch 48/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 0.9997
# Epoch 49/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0089 - accuracy: 0.9999 - val_loss: 0.0083 - val_accuracy: 0.9997
# Epoch 50/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0077 - accuracy: 0.9999 - val_loss: 0.0074 - val_accuracy: 0.9996

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14,4))
pd.DataFrame(training.history)[['accuracy', 'val_accuracy']].plot(ax=axes[0])
pd.DataFrame(training.history)[['loss', 'val_loss']].plot(ax=axes[1])
sns.despine()
fig.tight_layout();

# %% [markdown]
# ## Get Weights

# %%
hidden = model.get_layer('hidden').get_weights()

# %%
[t.shape for t in hidden]
# Out:
# [(2, 3), (3,)]

# %% [markdown]
# ## Plot Decision Boundary

# %% [markdown]
# The visualization of the decision boundary resembles the result from the manual network implementation. The training with Keras runs a multiple faster, though.

# %%
n_vals = 200
x1 = np.linspace(-1.5, 1.5, num=n_vals)
x2 = np.linspace(-1.5, 1.5, num=n_vals)
xx, yy = np.meshgrid(x1, x2)  # create the grid

# %%
X_ = np.array([xx.ravel(), yy.ravel()]).T

# %%
y_hat = np.argmax(model.predict(X_), axis=1)

# %%
# Create a color map to show the classification colors of each grid point
cmap = ListedColormap([sns.xkcd_rgb["pale red"],
                       sns.xkcd_rgb["denim blue"]])

# Plot the classification plane with decision boundary and input samples
plt.contourf(xx, yy, y_hat.reshape(n_vals, -1), cmap=cmap, alpha=.25)

# Plot both classes on the x1, x2 plane
data = pd.DataFrame(X, columns=['$x_1$', '$x_2$']).assign(Class=pd.Series(y).map({0:'negative', 1:'positive'}))
sns.scatterplot(x='$x_1$', y='$x_2$', hue='Class', data=data, style=y, markers=['_', '+'], legend=False)
sns.despine()
plt.title('Decision Boundary');

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir results/tensorboard/
# Out:
#       <iframe id="tensorboard-frame-d9fe2327f47dcc1e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d9fe2327f47dcc1e");
#           const url = new URL("/", window.location);
#           url.port = 6007;
#           frame.src = url;
#         })();
#       </script>
