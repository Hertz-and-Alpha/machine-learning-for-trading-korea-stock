# %% [markdown]
# # How to build a linear factor model

# %% [markdown]
# Algorithmic trading strategies use linear factor models to quantify the relationship between the return of an asset and the sources of risk that represent the main drivers of these returns. Each factor risk carries a premium, and the total asset return can be expected to correspond to a weighted average of these risk premia.

# %% [markdown]
# There are several practical applications of factor models across the portfolio management process from construction and asset selection to risk management and performance evaluation. The importance of factor models continues to grow as common risk factors are now tradeable:
#
# - A summary of the returns of many assets by a much smaller number of factors reduces the amount of data required to estimate the covariance matrix when optimizing a portfolio
# - An estimate of the exposure of an asset or a portfolio to these factors allows for the management of the resultant risk, for instance by entering suitable hedges when risk factors are themselves traded
# - A factor model also permits the assessment of the incremental signal content of new alpha factors
# - A factor model can also help assess whether a manager's performance relative to a benchmark is indeed due to skill in selecting assets and timing the market, or if instead, the performance can be explained by portfolio tilts towards known return drivers that can today be replicated as low-cost, passively managed funds without incurring active management fees

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

from statsmodels.api import OLS, add_constant
import pandas_datareader.data as web

from linearmodels.asset_pricing import LinearFactorModel

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')

# %% [markdown]
# ## Get Data

# %% [markdown]
# Fama and French make updated risk factor and research portfolio data available through their [website](http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html), and you can use the `pandas_datareader` package to obtain the data.

# %% [markdown]
# ### Risk Factors

# %% [markdown]
# In particular, we will be using the five Fama—French factors that result from sorting stocks first into three size groups and then into two for each of the remaining three firm-specific factors.
#
# Hence, the factors involve three sets of value-weighted portfolios formed as 3 x 2 sorts on size and book-to-market, size and operating profitability, and size and investment. The risk factor values computed as the average returns of the portfolios (PF) as outlined in the following table:

# %% [markdown]
# | Label | Name                          | Description                                                                                                                                                                               |
# |-------|-------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | SMB   | Small Minus Big               | Average return on the nine small stock portfolios minus the average return on the nine big stock portfolios                                                                               |
# | HML   | High Minus Low                | Average return on the two value portfolios minus the average return on the two growth portfolios                                                                                          |
# | RMW   | Robust minus Weak             | Average return on the two robust operating profitability portfolios minus the average return on the two weak operating profitability portfolios                                           |
# | CMA   | Conservative Minus Aggressive | Average return on the two conservative investment portfolios minus the average return on the two aggressive investment portfolios                                                         |
# | Rm-Rf | Excess return on the market   | Value-weight return of all firms incorporated in the US and listed on the NYSE, AMEX, or NASDAQ at the beginning of month t with 'good' data for t minus the one-month Treasury bill rate |

# %% [markdown]
# The Fama-French 5 factors are based on the 6 value-weight portfolios formed on size and book-to-market, the 6 value-weight portfolios formed on size and operating profitability, and the 6 value-weight portfolios formed on size and investment.

# %% [markdown]
# We will use returns at a monthly frequency that we obtain for the period 2010 – 2017 as follows:

# %%
with pd.HDFStore('../data/assets.h5') as store:
    ff_factor_data = store['fama_french/equal_weight/korea']

# %%
ff_factor_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 275 entries, 1998-07 to 2021-05
# Freq: M
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mkt-RF  275 non-null    float64
#  1   SMB     275 non-null    float64
#  2   HML     275 non-null    float64
#  3   RMW     275 non-null    float64
#  4   CMA     275 non-null    float64
#  5   RF      275 non-null    float64
# dtypes: float64(6)
# memory usage: 15.0 KB

# %%
ff_factor_data.describe()
# Out:
#            Mkt-RF         SMB         HML         RMW         CMA          RF
# count  275.000000  275.000000  275.000000  275.000000  275.000000  275.000000
# mean     1.236744    0.984802    0.704483   -0.013346   -0.808767    0.000363
# std      5.238973    3.003052    4.729552    2.914485    3.146677    0.015221
# min    -21.786403   -7.474589  -35.507899  -10.524656  -28.631149   -0.056600
# 25%     -1.690543   -0.875360   -0.840052   -1.642012   -2.211078   -0.005050
# 50%      1.094318    0.919895    0.851198    0.233739   -0.567571    0.000000
# 75%      3.773020    2.906032    2.755747    1.722634    0.923586    0.002450
# max     21.841657   14.101973   14.987152   12.767386   12.881358    0.119400

# %%
(ff_factor_data/100 + 1).cumprod().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Portfolios

# %% [markdown]
# Fama and French also make available numerous portfolios that we can illustrate the estimation of the factor exposures, as well as the value of the risk premia available in the market for a given time period. We will use a panel of the 17 industry portfolios at a monthly frequency.
#
# We will subtract the risk-free rate from the returns because the factor model works with excess returns:

# %%
with pd.HDFStore('../data/assets.h5') as store:
    ff_portfolio_data = store['kospi/sector_return']
ff_portfolio_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 288 entries, 1997-06 to 2021-05
# Freq: M
# Columns: 126 entries, 의약품 제조업 to 자연과학 및 공학 연구개발업
# dtypes: float64(126)
# memory usage: 285.8 KB

# %%
ff_portfolio_data
# Out:
#            의약품 제조업  그외 기타 운송장비 제조업     종합 소매업        보험업     기타 금융업  \
# date
# 1997-06   5.408983      -16.806818  -6.406562 -13.851618  -1.216831
# 1997-07  10.433507       -5.050460  -9.497945  -9.648911  -0.418684
# 1997-08  -1.860805      -10.638198  -1.742398  -2.889327  -2.142500
# 1997-09  -6.460884        1.190351 -10.005151  -3.697500  -7.116828
# 1997-10 -30.270576      -37.647044 -39.389633 -25.740434 -27.368536
# ...            ...             ...        ...        ...        ...
# 2021-01  -8.316389      -20.881057   3.596562  -2.966543  -0.497626
# 2021-02  -3.018822       37.527840   5.192366  10.882904   3.626380
# 2021-03  -3.915649        6.477733   7.142487   9.276332  13.860111
# 2021-04   6.935944       -5.323194   1.685752   3.623842   9.183015
# 2021-05   1.977856       -5.220884   1.248262   1.365851   0.291421
#
#          도로 화물 운송업  회사 본부 및 경영 컨설팅 서비스업  유리 및 유리제품 제조업  기타 전문 도매업  \
# date
# 1997-06   0.000000             0.000000       0.000000   0.000000
# 1997-07  11.539381             1.603827      -5.812865  10.074270
# 1997-08  -9.112924            -5.054586      -7.408419  -6.716416
# 1997-09  -3.576630            -4.151796      -9.071402  -4.384662
# 1997-10 -33.738239           -36.551672      -8.554572 -26.494132
# ...            ...                  ...            ...        ...
# 2021-01   0.257459            -1.050152     -10.249791  -6.365437
# 2021-02  18.129052            -2.480504      13.111921   6.100382
# 2021-03   0.648779             5.977739       7.813669  12.340648
# 2021-04   5.790658            19.110953      14.150754   1.819083
# 2021-05  -6.017842             2.610808       5.228320   1.478960
#
#          방적 및 가공사 제조업  ...   철도장비 제조업  산업용 농·축산물 및 동·식물 도매업  산업용 기계 및 장비 임대업  \
# date                   ...
# 1997-06      0.000000  ...   0.000000              0.000000         0.000000
# 1997-07      4.701689  ...   0.000000              0.000000         0.000000
# 1997-08     -0.841777  ...   0.000000              0.000000         0.000000
# 1997-09     -7.222764  ...   0.000000              0.000000         0.000000
# 1997-10     -4.479400  ...   0.000000              0.000000         0.000000
# ...               ...  ...        ...                   ...              ...
# 2021-01      6.582538  ...  11.918605             -4.773562       -13.109426
# 2021-02      1.047365  ...   1.818182              2.570694        -3.117207
# 2021-03     15.576414  ...   3.826531             27.568922        15.958816
# 2021-04      4.015338  ...  -0.982801             -0.982318        23.418424
# 2021-05      3.655220  ...   3.225806              6.150794         4.316547
#
#          음·식료품 및 담배 도매업  일반 및 생활 숙박시설 운영업  의료용 기기 제조업  개인 및 가정용품 임대업  \
# date
# 1997-06        0.000000          0.000000    0.000000       0.000000
# 1997-07        0.000000          0.000000    0.000000       0.000000
# 1997-08        0.000000          0.000000    0.000000       0.000000
# 1997-09        0.000000          0.000000    0.000000       0.000000
# 1997-10        0.000000          0.000000    0.000000       0.000000
# ...                 ...               ...         ...            ...
# 2021-01       -9.457478         -0.822562   12.408759       2.813299
# 2021-02       17.810745          9.004739   32.467532       0.870647
# 2021-03       -0.587595          4.456522    4.738562       5.548705
# 2021-04        4.826865          3.642040   -7.020281      -1.401869
# 2021-05       -3.797286          5.622490   -6.040268      15.639810
#
#          건물설비 설치 공사업  오디오물 출판 및 원판 녹음업  자연과학 및 공학 연구개발업
# date
# 1997-06     0.000000          0.000000         0.000000
# 1997-07     0.000000          0.000000         0.000000
# 1997-08     0.000000          0.000000         0.000000
# 1997-09     0.000000          0.000000         0.000000
# 1997-10     0.000000          0.000000         0.000000
# ...              ...               ...              ...
# 2021-01    -3.717472         27.812500         0.000000
# 2021-02     0.643501          0.977995         0.000000
# 2021-03     0.639386         17.675545       -27.319588
# 2021-04    20.838628          1.010101        20.035461
# 2021-05    -9.148265          7.613169       -14.918759
#
# [288 rows x 126 columns]

# %%
ff_portfolio_data.describe()
# Out:
#           의약품 제조업  그외 기타 운송장비 제조업      종합 소매업         보험업      기타 금융업  \
# count  288.000000      288.000000  288.000000  288.000000  288.000000
# mean     1.893636       -0.038462    1.376103    1.123083    1.518659
# std     10.773595       22.142118   11.020794   12.283050    8.864403
# min    -33.505112      -60.543838  -39.389633  -36.539502  -29.514872
# 25%     -3.885671      -11.205556   -3.353969   -4.272723   -2.677266
# 50%      0.674681       -3.053939    0.556621    0.279781    1.311435
# 75%      7.394587        6.505006    5.156358    4.306034    5.262472
# max     77.871841      159.997509   67.817730   57.114959   57.549143
#
#         도로 화물 운송업  회사 본부 및 경영 컨설팅 서비스업  유리 및 유리제품 제조업   기타 전문 도매업  \
# count  288.000000           288.000000     288.000000  288.000000
# mean     1.963010             1.419694       1.627292    0.721298
# std     12.180643             8.984809      17.245085    9.375648
# min    -33.738239           -36.551672     -70.592593  -29.333064
# 25%     -4.285164            -3.646023      -5.391340   -4.154024
# 50%      0.587230             0.852128      -0.428341    0.049305
# 75%      6.105999             6.445477       6.423472    5.409984
# max     54.530424            40.219363     151.889169   58.111277
#
#        방적 및 가공사 제조업  ...    철도장비 제조업  산업용 농·축산물 및 동·식물 도매업  산업용 기계 및 장비 임대업  \
# count    288.000000  ...  288.000000            288.000000       288.000000
# mean       0.790404  ...    0.074200             -0.003905         0.144450
# std        9.598994  ...    7.790828              4.938954         6.268400
# min      -29.029418  ...  -28.360656            -24.729242       -27.872861
# 25%       -3.827539  ...    0.000000              0.000000         0.000000
# 50%       -0.132777  ...    0.000000              0.000000         0.000000
# 75%        3.687365  ...    0.000000              0.000000         0.000000
# max       56.189353  ...   68.987342             27.568922        30.895522
#
#        음·식료품 및 담배 도매업  일반 및 생활 숙박시설 운영업  의료용 기기 제조업  개인 및 가정용품 임대업  \
# count      288.000000        288.000000  288.000000     288.000000
# mean        -0.152160         -0.043248    0.294672       0.159230
# std          4.444562          6.656576    5.072702       3.912230
# min        -32.706955        -28.440367  -28.059701     -26.932084
# 25%          0.000000          0.000000    0.000000       0.000000
# 50%          0.000000          0.000000    0.000000       0.000000
# 75%          0.000000          0.000000    0.000000       0.000000
# max         20.659810         51.888342   32.467532      23.121387
#
#        건물설비 설치 공사업  오디오물 출판 및 원판 녹음업  자연과학 및 공학 연구개발업
# count   288.000000        288.000000       288.000000
# mean     -0.121560          0.245258        -0.077093
# std       3.747862          2.602596         2.183752
# min     -34.090909        -10.863510       -27.319588
# 25%       0.000000          0.000000         0.000000
# 50%       0.000000          0.000000         0.000000
# 75%       0.000000          0.000000         0.000000
# max      20.838628         27.812500        20.035461
#
# [8 rows x 126 columns]

# %% [markdown]
# ### Equity Data

# %%
with pd.HDFStore('../data/assets.h5') as store:
    prices = store['/finance_datareader/prices'].adj_close.unstack().loc['2010':'2017']
    equities = store['/kospi/stocks'].drop_duplicates()

# %%
sectors = equities.filter(prices.columns, axis=0).sector.to_dict()
prices = prices.filter(sectors.keys()).dropna(how='all', axis=1)

# %%
returns = prices.resample('M').last().pct_change().mul(100).to_period('M')
returns = returns.dropna(how='all').dropna(axis=1)
returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 95 entries, 2010-02 to 2017-12
# Freq: M
# Columns: 579 entries, 000020 to 119650
# dtypes: float64(579)
# memory usage: 430.5 KB

# %% [markdown]
# ### Align data

# %%
ff_factor_data = ff_factor_data.loc[returns.index]
ff_portfolio_data = ff_portfolio_data.loc[returns.index]

# %%
ff_factor_data.describe()
# Out:
#           Mkt-RF        SMB        HML        RMW        CMA         RF
# count  95.000000  95.000000  95.000000  95.000000  95.000000  95.000000
# mean    0.873354   1.225817   0.885819  -0.403397  -0.587627  -0.001566
# std     3.321729   2.532338   2.619874   2.194833   2.154502   0.011133
# min    -8.442563  -4.136874  -7.300836  -6.392650  -7.349247  -0.036700
# 25%    -1.439244  -0.644407  -0.645956  -1.870899  -1.768727  -0.006000
# 50%     1.233214   1.367042   0.960851  -0.648977  -0.730715   0.000000
# 75%     2.998824   2.869824   2.417127   1.168012   0.981647   0.001000
# max     7.605933  11.342762   6.748551   5.145362   5.686852   0.076500

# %% [markdown]
# ### Compute excess Returns

# %%
excess_returns = returns.sub(ff_factor_data.RF, axis=0)
excess_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 95 entries, 2010-02 to 2017-12
# Freq: M
# Columns: 579 entries, 000020 to 119650
# dtypes: float64(579)
# memory usage: 430.5 KB

# %%
excess_returns = excess_returns.clip(lower=np.percentile(excess_returns, 1),
                                     upper=np.percentile(excess_returns, 99))

# %% [markdown]
# ## Fama-Macbeth Regression

# %% [markdown]
# Given data on risk factors and portfolio returns, it is useful to estimate the portfolio's exposure, that is, how much the risk factors drive portfolio returns, as well as how much the exposure to a given factor is worth, that is, the what market's risk factor premium is. The risk premium then permits to estimate the return for any portfolio provided the factor exposure is known or can be assumed.

# %%
ff_portfolio_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 95 entries, 2010-02 to 2017-12
# Freq: M
# Columns: 126 entries, 의약품 제조업 to 자연과학 및 공학 연구개발업
# dtypes: float64(126)
# memory usage: 94.3 KB

# %%
ff_factor_data = ff_factor_data.drop('RF', axis=1)
ff_factor_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 95 entries, 2010-02 to 2017-12
# Freq: M
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mkt-RF  95 non-null     float64
#  1   SMB     95 non-null     float64
#  2   HML     95 non-null     float64
#  3   RMW     95 non-null     float64
#  4   CMA     95 non-null     float64
# dtypes: float64(5)
# memory usage: 4.5 KB

# %% [markdown]
# To address the inference problem caused by the correlation of the residuals, Fama and MacBeth proposed a two-step methodology for a cross-sectional regression of returns on factors. The two-stage Fama—Macbeth regression is designed to estimate the premium rewarded for the exposure to a particular risk factor by the market. The two stages consist of:
#
# - First stage: N time-series regression, one for each asset or portfolio, of its excess returns on the factors to estimate the factor loadings.
#
# - Second stage: T cross-sectional regression, one for each time period, to estimate the risk premium.
#
# See corresponding section in Chapter 7 of [Machine Learning for Trading](https://www.amazon.com/Hands-Machine-Learning-Algorithmic-Trading-ebook/dp/B07JLFH7C5/ref=sr_1_2?ie=UTF8&qid=1548455634&sr=8-2&keywords=machine+learning+algorithmic+trading) for details.

# %% [markdown]
# Now we can compute the factor risk premia as the time average and get t-statistic to assess their individual significance, using the assumption that the risk premia estimates are independent over time.
#
# If we had a very large and representative data sample on traded risk factors we could use the sample mean as a risk premium estimate. However, we typically do not have a sufficiently long history to and the margin of error around the sample mean could be quite large.
#
# The Fama—Macbeth methodology leverages the covariance of the factors with other assets to determine the factor premia. The second moment of asset returns is easier to estimate than the first moment, and obtaining more granular data improves estimation considerably, which is not true of mean estimation.

# %% [markdown]
# ### Step 1: Factor Exposures

# %% [markdown]
# We can implement the first stage to obtain the 17 factor loading estimates as follows:

# %%
betas = []
for industry in ff_portfolio_data:
    step1 = OLS(endog=ff_portfolio_data.loc[ff_factor_data.index, industry], 
                exog=add_constant(ff_factor_data)).fit()
    betas.append(step1.params.drop('const'))

# %%
betas = pd.DataFrame(betas, 
                     columns=ff_factor_data.columns, 
                     index=ff_portfolio_data.columns)
betas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126 entries, 의약품 제조업 to 자연과학 및 공학 연구개발업
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mkt-RF  126 non-null    float64
#  1   SMB     126 non-null    float64
#  2   HML     126 non-null    float64
#  3   RMW     126 non-null    float64
#  4   CMA     126 non-null    float64
# dtypes: float64(5)
# memory usage: 10.0+ KB

# %% [markdown]
# ### Step 2: Risk Premia

# %% [markdown]
# For the second stage, we run 96 regressions of the period returns for the cross section of portfolios on the factor loadings

# %%
lambdas = []
for period in ff_portfolio_data.index:
    step2 = OLS(endog=ff_portfolio_data.loc[period, betas.index], 
                exog=betas).fit()
    lambdas.append(step2.params)

# %%
lambdas = pd.DataFrame(lambdas, 
                       index=ff_portfolio_data.index,
                       columns=betas.columns.tolist())
lambdas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 95 entries, 2010-02 to 2017-12
# Freq: M
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mkt-RF  95 non-null     float64
#  1   SMB     95 non-null     float64
#  2   HML     95 non-null     float64
#  3   RMW     95 non-null     float64
#  4   CMA     95 non-null     float64
# dtypes: float64(5)
# memory usage: 9.3 KB

# %%
lambdas.mean().sort_values().plot.barh(figsize=(12, 4))
sns.despine()
plt.tight_layout();

# %%
t = lambdas.mean().div(lambdas.std())
t
# Out:
# Mkt-RF    0.216337
# SMB       0.118718
# HML      -0.103326
# RMW       0.014226
# CMA      -0.039213
# dtype: float64

# %% [markdown]
# #### Results

# %%
window = 24  # months
ax1 = plt.subplot2grid((1, 3), (0, 0))
ax2 = plt.subplot2grid((1, 3), (0, 1), colspan=2)
lambdas.mean().sort_values().plot.barh(ax=ax1)
lambdas.rolling(window).mean().dropna().plot(lw=1,
                                             figsize=(14, 5),
                                             sharey=True,
                                             ax=ax2)
sns.despine()
plt.tight_layout()

# %%
window = 24  # months
lambdas.rolling(window).mean().dropna().plot(lw=2,
                                             figsize=(14, 7),
                                             subplots=True,
                                             sharey=True)
sns.despine()
plt.tight_layout()

# %% [markdown]
# ## Fama-Macbeth with the LinearModels library

# %% [markdown]
# The linear_models library extends statsmodels with various models for panel data and also implements the two-stage Fama—MacBeth procedure:

# %%
mod = LinearFactorModel(portfolios=ff_portfolio_data, 
                        factors=ff_factor_data)
res = mod.fit()
print(res)
# Out:
#                       LinearFactorModel Estimation Summary
# ================================================================================
# No. Test Portfolios:                126   R-squared:                      0.2093
# No. Factors:                          5   J-statistic:                    438.03
# No. Observations:                    95   P-value                         0.0000
# Date:                  Fri, Jun 25 2021   Distribution:                chi2(121)
# Time:                          16:12:07
# Cov. Estimator:                  robust
#
#                             Risk Premia Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Mkt-RF         0.7289     0.3735     1.9519     0.0510     -0.0030      1.4609
# SMB            0.4181     0.4979     0.8398     0.4010     -0.5577      1.3939
# HML           -0.4754     0.6258    -0.7596     0.4475     -1.7019      0.7512
# RMW            0.0492     0.4226     0.1164     0.9073     -0.7791      0.8775
# CMA           -0.1528     0.5150    -0.2966     0.7668     -1.1622      0.8567
# ==============================================================================
#
# Covariance estimator:
# HeteroskedasticCovariance
# See full_summary for complete results

# %%
print(res.full_summary)
# Out:
#                       LinearFactorModel Estimation Summary
# ================================================================================
# No. Test Portfolios:                126   R-squared:                      0.2093
# No. Factors:                          5   J-statistic:                    438.03
# No. Observations:                    95   P-value                         0.0000
# Date:                  Fri, Jun 25 2021   Distribution:                chi2(121)
# Time:                          16:12:07
# Cov. Estimator:                  robust
#
#                             Risk Premia Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Mkt-RF         0.7289     0.3735     1.9519     0.0510     -0.0030      1.4609
# SMB            0.4181     0.4979     0.8398     0.4010     -0.5577      1.3939
# HML           -0.4754     0.6258    -0.7596     0.4475     -1.7019      0.7512
# RMW            0.0492     0.4226     0.1164     0.9073     -0.7791      0.8775
# CMA           -0.1528     0.5150    -0.2966     0.7668     -1.1622      0.8567
#
#
#                              의약품 제조업 Coefficients
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# alpha          0.6350     0.7200     0.8819     0.3778     -0.7762      2.0461
# Mkt-RF         1.3318     0.1375     9.6857     0.0000      1.0623      1.6013
# SMB           -0.0608     0.2729    -0.2226     1.1762     -0.5957      0.4742
# HML           -0.7086     0.2140    -3.3112     1.9991     -1.1281     -0.2892
# RMW           -0.2271     0.3549    -0.6399     1.4778     -0.9227      0.4685
# CMA            0.2190     0.2774     0.7894     0.4299     -0.3247      0.7627
#
#
#                          그외 기타 운송장비 제조업 Coefficients
# ==============================================================================
# alpha         -0.7554     1.3417    -0.5630     1.4266     -3.3851      1.8743
# Mkt-RF         1.3842     0.4122     3.3583     0.0008      0.5763      2.1920
# SMB            1.1971     0.7910     1.5134     0.1302     -0.3532      2.7475
# HML            0.0872     0.5229     0.1668     0.8675     -0.9377      1.1122
# RMW           -1.1364     0.6553    -1.7341     1.9171     -2.4207      0.1480
# CMA            1.5537     0.7496     2.0728     0.0382      0.0846      3.0229
#
#
#                              종합 소매업 Coefficients
# ==============================================================================
# alpha          0.4313     0.3735     1.1549     0.2481     -0.3007      1.1634
# Mkt-RF         0.6662     0.1299     5.1299     0.0000      0.4117      0.9207
# SMB           -0.5760     0.1438    -4.0063     1.9999     -0.8578     -0.2942
# HML            0.3215     0.1222     2.6319     0.0085      0.0821      0.5610
# RMW            0.2313     0.1833     1.2618     0.2070     -0.1280      0.5905
# CMA           -0.3108     0.1730    -1.7964     1.9276     -0.6498      0.0283
#
#
#                                보험업 Coefficients
# ==============================================================================
# alpha          0.1860     0.4903     0.3794     0.7044     -0.7749      1.1470
# Mkt-RF         0.6358     0.1401     4.5393     0.0000      0.3613      0.9104
# SMB           -0.4211     0.1823    -2.3096     1.9791     -0.7784     -0.0637
# HML            0.1580     0.1679     0.9409     0.3468     -0.1711      0.4871
# RMW           -0.1708     0.2241    -0.7620     1.5540     -0.6100      0.2685
# CMA            0.0287     0.2387     0.1201     0.9044     -0.4391      0.4965
#
#
#                              기타 금융업 Coefficients
# ==============================================================================
# alpha          0.5387     0.2568     2.0979     0.0359      0.0354      1.0419
# Mkt-RF         1.1915     0.0593     20.089     0.0000      1.0753      1.3078
# SMB           -0.3622     0.0965    -3.7537     1.9998     -0.5513     -0.1731
# HML            0.2545     0.0997     2.5523     0.0107      0.0591      0.4499
# RMW            0.0942     0.1322     0.7129     0.4759     -0.1648      0.3533
# CMA           -0.0102     0.0883    -0.1152     1.0917     -0.1833      0.1629
#
#
#                             도로 화물 운송업 Coefficients
# ==============================================================================
# alpha          0.0992     0.4543     0.2184     0.8271     -0.7912      0.9897
# Mkt-RF         1.2126     0.1317     9.2104     0.0000      0.9546      1.4706
# SMB            0.4072     0.1768     2.3026     0.0213      0.0606      0.7538
# HML            0.2832     0.1820     1.5561     0.1197     -0.0735      0.6399
# RMW           -0.1144     0.1906    -0.6002     1.4516     -0.4880      0.2592
# CMA            0.2209     0.1855     1.1904     0.2339     -0.1428      0.5845
#
#
#                        회사 본부 및 경영 컨설팅 서비스업 Coefficients
# ==============================================================================
# alpha          0.5687     0.3834     1.4833     0.1380     -0.1828      1.3203
# Mkt-RF         1.1992     0.1050     11.423     0.0000      0.9934      1.4050
# SMB           -0.0763     0.2030    -0.3760     1.2931     -0.4743      0.3216
# HML            0.2448     0.1406     1.7417     0.0816     -0.0307      0.5203
# RMW           -0.0358     0.1876    -0.1907     1.1512     -0.4035      0.3320
# CMA            0.2204     0.2907     0.7581     0.4484     -0.3493      0.7901
#
#
#                           유리 및 유리제품 제조업 Coefficients
# ==============================================================================
# alpha          0.5039     1.0308     0.4888     0.6250     -1.5165      2.5243
# Mkt-RF         1.1311     0.3251     3.4788     0.0005      0.4938      1.7684
# SMB            0.2761     0.5987     0.4612     0.6446     -0.8973      1.4496
# HML            0.3703     0.4234     0.8744     0.3819     -0.4597      1.2002
# RMW            0.5330     0.7030     0.7582     0.4483     -0.8449      1.9110
# CMA           -0.7787     0.6395    -1.2176     1.7766     -2.0320      0.4747
#
#
#                             기타 전문 도매업 Coefficients
# ==============================================================================
# alpha          0.1268     0.4002     0.3169     0.7513     -0.6576      0.9112
# Mkt-RF         1.0487     0.1066     9.8386     0.0000      0.8398      1.2576
# SMB            0.5037     0.1495     3.3699     0.0008      0.2107      0.7966
# HML           -0.0363     0.1543    -0.2350     1.1858     -0.3386      0.2661
# RMW           -0.2906     0.1527    -1.9035     1.9430     -0.5898      0.0086
# CMA           -0.1307     0.2072    -0.6309     1.4719     -0.5369      0.2754
#
#
#                           방적 및 가공사 제조업 Coefficients
# ==============================================================================
# alpha          0.4129     1.0026     0.4119     0.6804     -1.5520      2.3779
# Mkt-RF         0.8869     0.2764     3.2087     0.0013      0.3452      1.4286
# SMB           -0.1606     0.3720    -0.4317     1.3340     -0.8897      0.5685
# HML            0.4951     0.3315     1.4933     0.1354     -0.1547      1.1448
# RMW            0.1155     0.5380     0.2146     0.8301     -0.9390      1.1699
# CMA           -0.3480     0.4120    -0.8447     1.6017     -1.1555      0.4595
#
#
#                          기타 금속 가공제품 제조업 Coefficients
# ==============================================================================
# alpha          0.8591     1.6533     0.5196     0.6033     -2.3813      4.0994
# Mkt-RF         1.9400     0.9275     2.0916     0.0365      0.1221      3.7579
# SMB            1.4678     1.0517     1.3956     0.1628     -0.5935      3.5292
# HML           -0.0074     1.8861    -0.0039     1.0031     -3.7040      3.6892
# RMW            1.8152     1.3116     1.3839     0.1664     -0.7556      4.3859
# CMA           -0.8428     1.0456    -0.8060     1.5798     -2.8922      1.2066
#
#
#                       골판지, 종이 상자 및 종이용기 제조업 Coefficients
# ==============================================================================
# alpha          0.0358     0.6778     0.0528     0.9579     -1.2927      1.3642
# Mkt-RF         0.9943     0.1300     7.6464     0.0000      0.7395      1.2492
# SMB            0.8929     0.2163     4.1274     0.0000      0.4689      1.3169
# HML           -0.0189     0.2329    -0.0811     1.0646     -0.4754      0.4376
# RMW            0.2213     0.2712     0.8159     0.4146     -0.3103      0.7528
# CMA            0.2756     0.2526     1.0912     0.2752     -0.2195      0.7707
#
#
#                       비료, 농약 및 살균, 살충제 제조업 Coefficients
# ==============================================================================
# alpha         -0.4075     0.5412    -0.7530     1.5485     -1.4684      0.6533
# Mkt-RF         0.7624     0.1421     5.3666     0.0000      0.4840      1.0409
# SMB            0.4760     0.2112     2.2539     0.0242      0.0621      0.8899
# HML           -0.3747     0.2367    -1.5831     1.8866     -0.8386      0.0892
# RMW            0.5211     0.4609     1.1307     0.2582     -0.3822      1.4244
# CMA           -0.0835     0.2125    -0.3931     1.3058     -0.4999      0.3329
#
#
#                          통신 및 방송 장비 제조업 Coefficients
# ==============================================================================
# alpha          0.0901     0.5492     0.1641     0.8696     -0.9862      1.1665
# Mkt-RF         0.7703     0.1509     5.1058     0.0000      0.4746      1.0660
# SMB            0.3865     0.2603     1.4852     0.1375     -0.1236      0.8966
# HML           -0.0510     0.1863    -0.2735     1.2155     -0.4161      0.3142
# RMW           -0.6467     0.4200    -1.5399     1.8764     -1.4698      0.1764
# CMA            0.2189     0.3410     0.6419     0.5210     -0.4495      0.8873
#
#
#                            기타 화학제품 제조업 Coefficients
# ==============================================================================
# alpha          0.8262     0.3427     2.4108     0.0159      0.1545      1.4978
# Mkt-RF         1.3068     0.0867     15.067     0.0000      1.1368      1.4768
# SMB           -0.1806     0.1042    -1.7324     1.9168     -0.3849      0.0237
# HML           -0.1819     0.1056    -1.7226     1.9150     -0.3889      0.0251
# RMW            0.2011     0.1322     1.5216     0.1281     -0.0579      0.4601
# CMA            0.0474     0.1534     0.3092     0.7571     -0.2532      0.3481
#
#
#                           자동차 신품 부품 제조업 Coefficients
# ==============================================================================
# alpha          0.5227     0.3804     1.3742     0.1694     -0.2228      1.2682
# Mkt-RF         1.2472     0.1154     10.809     0.0000      1.0211      1.4734
# SMB            0.0009     0.1821     0.0051     0.9959     -0.3559      0.3578
# HML            0.2483     0.1433     1.7332     0.0831     -0.0325      0.5291
# RMW           -0.1887     0.2091    -0.9025     1.6332     -0.5986      0.2211
# CMA           -0.0235     0.2112    -0.1111     1.0885     -0.4373      0.3904
#
#
#                         내화, 비내화 요업제품 제조업 Coefficients
# ==============================================================================
# alpha          0.6791     0.6925     0.9806     0.3268     -0.6783      2.0364
# Mkt-RF         1.2690     0.1838     6.9043     0.0000      0.9088      1.6293
# SMB            0.3963     0.2388     1.6594     0.0970     -0.0718      0.8644
# HML            0.2547     0.2350     1.0835     0.2786     -0.2060      0.7153
# RMW            0.0540     0.2558     0.2113     0.8327     -0.4472      0.5553
# CMA           -0.1725     0.2736    -0.6304     1.4716     -0.7087      0.3637
#
#
#                           특수 목적용 기계 제조업 Coefficients
# ==============================================================================
# alpha         -0.0527     0.3866    -0.1364     1.1085     -0.8104      0.7049
# Mkt-RF         1.3796     0.1189     11.600     0.0000      1.1465      1.6126
# SMB            0.1157     0.1321     0.8760     0.3810     -0.1432      0.3747
# HML            0.1831     0.1176     1.5562     0.1197     -0.0475      0.4137
# RMW            0.3180     0.1660     1.9156     0.0554     -0.0074      0.6434
# CMA           -0.2232     0.1571    -1.4212     1.8447     -0.5311      0.0846
#
#
#                           절연선 및 케이블 제조업 Coefficients
# ==============================================================================
# alpha         -2.0077     0.6365    -3.1544     1.9984     -3.2552     -0.7602
# Mkt-RF         1.2732     0.1535     8.2939     0.0000      0.9724      1.5741
# SMB            0.3129     0.2963     1.0559     0.2910     -0.2679      0.8936
# HML           -0.2496     0.2739    -0.9110     1.6377     -0.7865      0.2873
# RMW           -0.1121     0.3970    -0.2824     1.2223     -0.8901      0.6659
# CMA           -0.3644     0.3524    -1.0341     1.6989     -1.0550      0.3263
#
#
#                             육상 여객 운송업 Coefficients
# ==============================================================================
# alpha          0.1298     0.7847     0.1654     0.8686     -1.4081      1.6677
# Mkt-RF         0.7284     0.2127     3.4236     0.0006      0.3114      1.1453
# SMB            0.9350     0.2982     3.1354     0.0017      0.3505      1.5195
# HML            0.0696     0.2035     0.3418     0.7325     -0.3293      0.4684
# RMW            0.5632     0.2802     2.0096     0.0445      0.0139      1.1124
# CMA            0.3259     0.3066     1.0631     0.2878     -0.2750      0.9268
#
#
#                              반도체 제조업 Coefficients
# ==============================================================================
# alpha          0.2286     0.6319     0.3617     0.7176     -1.0099      1.4671
# Mkt-RF         1.4696     0.1971     7.4548     0.0000      1.0832      1.8560
# SMB           -0.1219     0.3228    -0.3777     1.2943     -0.7546      0.5108
# HML            0.0913     0.3024     0.3019     0.7627     -0.5015      0.6841
# RMW           -0.3163     0.3877    -0.8157     1.5853     -1.0762      0.4437
# CMA           -0.1161     0.3489    -0.3326     1.2606     -0.8000      0.5678
#
#
#                             상품 종합 도매업 Coefficients
# ==============================================================================
# alpha         -1.1057     0.7537    -1.4670     1.8576     -2.5829      0.3715
# Mkt-RF         1.6489     0.2122     7.7689     0.0000      1.2329      2.0648
# SMB           -0.6403     0.3956    -1.6185     1.8944     -1.4157      0.1351
# HML            0.2161     0.2694     0.8023     0.4224     -0.3119      0.7441
# RMW            0.0364     0.3802     0.0956     0.9238     -0.7088      0.7815
# CMA           -0.7168     0.3239    -2.2131     1.9731     -1.3516     -0.0820
#
#
#                              토목 건설업 Coefficients
# ==============================================================================
# alpha         -0.7987     0.7568    -1.0553     1.7087     -2.2820      0.6847
# Mkt-RF         1.8278     0.1427     12.812     0.0000      1.5482      2.1074
# SMB           -0.8644     0.2693    -3.2097     1.9987     -1.3922     -0.3366
# HML            0.5101     0.2702     1.8881     0.0590     -0.0194      1.0396
# RMW           -0.6640     0.3326    -1.9963     1.9541     -1.3158     -0.0121
# CMA           -0.2551     0.2882    -0.8851     1.6239     -0.8200      0.3098
#
#
#                             알코올음료 제조업 Coefficients
# ==============================================================================
# alpha         -0.0085     0.8073    -0.0106     1.0084     -1.5908      1.5738
# Mkt-RF         1.2748     0.2106     6.0544     0.0000      0.8621      1.6875
# SMB            0.5916     0.3332     1.7755     0.0758     -0.0615      1.2447
# HML            0.1697     0.3177     0.5344     0.5931     -0.4529      0.7923
# RMW           -0.0465     0.5297    -0.0878     1.0700     -1.0847      0.9917
# CMA            0.0616     0.2918     0.2112     0.8328     -0.5102      0.6335
#
#
#                     시멘트, 석회, 플라스터 및 그 제품 제조업 Coefficients
# ==============================================================================
# alpha         -0.4404     0.6069    -0.7256     1.5319     -1.6298      0.7491
# Mkt-RF         1.5029     0.2095     7.1729     0.0000      1.0922      1.9136
# SMB            0.1293     0.3165     0.4084     0.6829     -0.4911      0.7496
# HML           -0.2493     0.2680    -0.9301     1.6477     -0.7746      0.2760
# RMW           -0.0139     0.3582    -0.0388     1.0309     -0.7160      0.6882
# CMA           -0.1920     0.3954    -0.4856     1.3727     -0.9669      0.5829
#
#
#                             1차 철강 제조업 Coefficients
# ==============================================================================
# alpha         -0.4904     0.3538    -1.3861     1.8343     -1.1838      0.2030
# Mkt-RF         1.3557     0.0959     14.131     0.0000      1.1676      1.5437
# SMB           -0.0017     0.1545    -0.0111     1.0088     -0.3046      0.3011
# HML            0.2615     0.1383     1.8900     0.0588     -0.0097      0.5326
# RMW            0.1109     0.1568     0.7075     0.4793     -0.1964      0.4183
# CMA           -0.0736     0.1663    -0.4426     1.3419     -0.3997      0.2524
#
#
#                          펄프, 종이 및 판지 제조업 Coefficients
# ==============================================================================
# alpha         -0.8691     0.4260    -2.0403     1.9587     -1.7039     -0.0342
# Mkt-RF         1.1914     0.1050     11.343     0.0000      0.9855      1.3973
# SMB            0.3081     0.1784     1.7273     0.0841     -0.0415      0.6577
# HML           -0.1875     0.1548    -1.2112     1.7742     -0.4909      0.1159
# RMW           -0.1256     0.1779    -0.7062     1.5199     -0.4743      0.2231
# CMA           -0.1706     0.2109    -0.8086     1.5812     -0.5840      0.2429
#
#
#                          직물직조 및 직물제품 제조업 Coefficients
# ==============================================================================
# alpha          0.4459     0.7851     0.5679     0.5701     -1.0930      1.9848
# Mkt-RF         1.2612     0.2329     5.4160     0.0000      0.8048      1.7177
# SMB            0.8247     0.3529     2.3367     0.0195      0.1330      1.5164
# HML            0.0103     0.3094     0.0333     0.9734     -0.5962      0.6168
# RMW           -0.5619     0.3176    -1.7691     1.9231     -1.1845      0.0606
# CMA           -0.0894     0.3942    -0.2267     1.1793     -0.8619      0.6832
#
#
#                              상품 중개업 Coefficients
# ==============================================================================
# alpha         -0.1993     1.1397    -0.1749     1.1388     -2.4331      2.0345
# Mkt-RF         1.0614     0.2474     4.2902     0.0000      0.5765      1.5463
# SMB            0.6227     0.3900     1.5965     0.1104     -0.1418      1.3871
# HML           -0.8234     0.4130    -1.9939     1.9538     -1.6328     -0.0140
# RMW            0.7892     0.3671     2.1498     0.0316      0.0697      1.5087
# CMA           -0.8594     0.5490    -1.5654     1.8825     -1.9353      0.2166
#
#
#                       곡물가공품, 전분 및 전분제품 제조업 Coefficients
# ==============================================================================
# alpha          0.6310     0.6548     0.9637     0.3352     -0.6524      1.9144
# Mkt-RF         0.9654     0.1713     5.6356     0.0000      0.6297      1.3012
# SMB            0.3804     0.2916     1.3049     0.1919     -0.1910      0.9519
# HML           -0.0950     0.2675    -0.3552     1.2776     -0.6193      0.4292
# RMW           -0.2159     0.3225    -0.6695     1.4968     -0.8479      0.4161
# CMA            0.0483     0.3431     0.1406     0.8882     -0.6242      0.7207
#
#
#                            금융 지원 서비스업 Coefficients
# ==============================================================================
# alpha         -0.4144     0.6116    -0.6777     1.5020     -1.6131      0.7842
# Mkt-RF         1.5306     0.1434     10.676     0.0000      1.2496      1.8116
# SMB           -0.4102     0.2110    -1.9440     1.9481     -0.8239      0.0034
# HML            0.4735     0.1950     2.4288     0.0151      0.0914      0.8557
# RMW           -0.3034     0.2718    -1.1161     1.7356     -0.8361      0.2294
# CMA            0.2921     0.2506     1.1656     0.2438     -0.1990      0.7831
#
#
#                           전구 및 조명장치 제조업 Coefficients
# ==============================================================================
# alpha         -2.1957     1.2708    -1.7278     1.9160     -4.6863      0.2950
# Mkt-RF         1.6350     0.3418     4.7839     0.0000      0.9651      2.3049
# SMB           -0.2428     0.5013    -0.4844     1.3719     -1.2253      0.7397
# HML            0.4203     0.3972     1.0580     0.2900     -0.3583      1.1988
# RMW           -0.7940     0.6738    -1.1784     1.7614     -2.1146      0.5266
# CMA           -0.9858     0.9654    -1.0211     1.6928     -2.8779      0.9063
#
#
#                            기초 화학물질 제조업 Coefficients
# ==============================================================================
# alpha          0.5428     0.4079     1.3309     0.1832     -0.2566      1.3422
# Mkt-RF         1.4206     0.0942     15.083     0.0000      1.2360      1.6052
# SMB           -0.5071     0.1543    -3.2856     1.9990     -0.8096     -0.2046
# HML            0.1249     0.1353     0.9232     0.3559     -0.1403      0.3900
# RMW            0.2610     0.1501     1.7389     0.0821     -0.0332      0.5553
# CMA           -0.1421     0.1748    -0.8127     1.5836     -0.4847      0.2005
#
#
#                             봉제의복 제조업 Coefficients
# ==============================================================================
# alpha          0.7202     0.5202     1.3846     0.1662     -0.2993      1.7398
# Mkt-RF         1.0607     0.1542     6.8784     0.0000      0.7585      1.3629
# SMB            0.0190     0.1762     0.1080     0.9140     -0.3263      0.3643
# HML            0.0451     0.1798     0.2511     0.8017     -0.3072      0.3975
# RMW            0.1059     0.2285     0.4634     0.6431     -0.3420      0.5537
# CMA            0.2617     0.2250     1.1633     0.2447     -0.1793      0.7028
#
#
#                             기타 식품 제조업 Coefficients
# ==============================================================================
# alpha          1.2721     0.6045     2.1044     0.0353      0.0873      2.4569
# Mkt-RF         1.1297     0.1505     7.5075     0.0000      0.8348      1.4246
# SMB           -0.0024     0.2564    -0.0095     1.0076     -0.5049      0.5001
# HML            0.1186     0.2214     0.5357     0.5922     -0.3153      0.5525
# RMW            0.0399     0.3134     0.1274     0.8987     -0.5744      0.6542
# CMA            0.3928     0.2977     1.3194     0.1870     -0.1907      0.9763
#
#
#                             전자부품 제조업 Coefficients
# ==============================================================================
# alpha          0.6208     0.6689     0.9281     0.3533     -0.6902      1.9318
# Mkt-RF         1.1339     0.2018     5.6190     0.0000      0.7384      1.5294
# SMB            0.2664     0.3002     0.8875     0.3748     -0.3219      0.8548
# HML           -0.6501     0.2661    -2.4433     1.9854     -1.1716     -0.1286
# RMW           -0.2718     0.3173    -0.8564     1.6082     -0.8937      0.3502
# CMA           -0.2309     0.4117    -0.5609     1.4251     -1.0378      0.5760
#
#
#                              건물 건설업 Coefficients
# ==============================================================================
# alpha         -0.3079     0.8276    -0.3720     1.2901     -1.9299      1.3142
# Mkt-RF         1.6006     0.1909     8.3848     0.0000      1.2264      1.9747
# SMB           -0.7213     0.2977    -2.4228     1.9846     -1.3048     -0.1378
# HML            0.4381     0.2662     1.6460     0.0998     -0.0836      0.9597
# RMW           -0.5961     0.3944    -1.5113     1.8693     -1.3692      0.1770
# CMA           -0.3501     0.4176    -0.8384     1.5982     -1.1685      0.4683
#
#
#                         가죽, 가방 및 유사제품 제조업 Coefficients
# ==============================================================================
# alpha          0.1881     0.9356     0.2011     0.8406     -1.6456      2.0218
# Mkt-RF         0.8082     0.2705     2.9881     0.0028      0.2781      1.3383
# SMB            0.0245     0.3655     0.0671     0.9465     -0.6918      0.7408
# HML           -0.1844     0.3250    -0.5673     1.4295     -0.8215      0.4527
# RMW           -0.2069     0.4617    -0.4480     1.3459     -1.1119      0.6981
# CMA            0.3050     0.3963     0.7695     0.4416     -0.4718      1.0818
#
#
#                         낙농제품 및 식용빙과류 제조업 Coefficients
# ==============================================================================
# alpha          0.5638     0.6040     0.9334     0.3506     -0.6201      1.7476
# Mkt-RF         0.9088     0.1732     5.2487     0.0000      0.5695      1.2482
# SMB           -0.5575     0.2005    -2.7805     1.9946     -0.9504     -0.1645
# HML            0.3642     0.2135     1.7060     0.0880     -0.0542      0.7826
# RMW            0.2956     0.2531     1.1679     0.2429     -0.2005      0.7916
# CMA           -0.0855     0.2369    -0.3610     1.2819     -0.5499      0.3789
#
#
#                             고무제품 제조업 Coefficients
# ==============================================================================
# alpha          0.5843     0.5459     1.0704     0.2844     -0.4856      1.6542
# Mkt-RF         0.8104     0.1544     5.2495     0.0000      0.5078      1.1129
# SMB           -0.0822     0.2917    -0.2819     1.2220     -0.6541      0.4896
# HML           -0.0096     0.2086    -0.0460     1.0367     -0.4184      0.3992
# RMW           -0.0916     0.2688    -0.3408     1.2668     -0.6185      0.4352
# CMA            0.1891     0.3036     0.6229     0.5334     -0.4060      0.7842
#
#
#                              악기 제조업 Coefficients
# ==============================================================================
# alpha          0.3269     1.3128     0.2490     0.8033     -2.2461      2.8999
# Mkt-RF         1.7714     0.4181     4.2367     0.0000      0.9519      2.5909
# SMB            0.1199     0.8200     0.1462     0.8838     -1.4873      1.7271
# HML           -0.3948     0.5444    -0.7252     1.5317     -1.4617      0.6722
# RMW            0.2696     0.7130     0.3781     0.7054     -1.1279      1.6671
# CMA           -0.0486     0.6630    -0.0732     1.0584     -1.3481      1.2510
#
#
#                             나무제품 제조업 Coefficients
# ==============================================================================
# alpha         -1.0691     1.0035    -1.0653     1.7133     -3.0360      0.8978
# Mkt-RF         1.6562     0.2666     6.2134     0.0000      1.1338      2.1786
# SMB            1.4234     0.4488     3.1712     0.0015      0.5437      2.3031
# HML           -0.0899     0.3859    -0.2330     1.1842     -0.8462      0.6664
# RMW            0.0601     0.3985     0.1509     0.8801     -0.7209      0.8412
# CMA            0.2935     0.6578     0.4462     0.6555     -0.9957      1.5828
#
#
#                            석유 정제품 제조업 Coefficients
# ==============================================================================
# alpha          0.6423     0.5368     1.1965     0.2315     -0.4099      1.6945
# Mkt-RF         1.0254     0.1196     8.5751     0.0000      0.7910      1.2598
# SMB           -0.2445     0.2089    -1.1703     1.7581     -0.6540      0.1650
# HML            0.1757     0.1919     0.9155     0.3599     -0.2004      0.5517
# RMW            0.4251     0.2240     1.8976     0.0577     -0.0140      0.8641
# CMA            0.0331     0.2710     0.1221     0.9029     -0.4980      0.5641
#
#
#                         기계장비 및 관련 물품 도매업 Coefficients
# ==============================================================================
# alpha          0.5677     0.8184     0.6936     0.4879     -1.0364      2.1717
# Mkt-RF         0.7003     0.2574     2.7211     0.0065      0.1959      1.2047
# SMB            0.9446     0.3664     2.5780     0.0099      0.2265      1.6628
# HML           -0.6520     0.3063    -2.1285     1.9667     -1.2524     -0.0516
# RMW           -0.0343     0.3518    -0.0976     1.0777     -0.7238      0.6551
# CMA            0.0013     0.3843     0.0034     0.9973     -0.7518      0.7544
#
#
#               측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외 Coefficients
# ==============================================================================
# alpha          0.9344     1.1540     0.8097     0.4181     -1.3274      3.1961
# Mkt-RF         1.5138     0.3212     4.7133     0.0000      0.8843      2.1433
# SMB           -0.0574     0.4476    -0.1282     1.1020     -0.9346      0.8199
# HML            0.1100     0.4067     0.2704     0.7868     -0.6872      0.9071
# RMW           -1.3319     0.5239    -2.5421     1.9890     -2.3588     -0.3050
# CMA           -0.6727     0.6877    -0.9782     1.6720     -2.0205      0.6751
#
#
#                             화학섬유 제조업 Coefficients
# ==============================================================================
# alpha          0.2347     0.7174     0.3271     0.7436     -1.1715      1.6408
# Mkt-RF         1.4839     0.2233     6.6445     0.0000      1.0462      1.9217
# SMB           -0.4151     0.3010    -1.3789     1.8321     -1.0050      0.1749
# HML            0.4283     0.2526     1.6953     0.0900     -0.0669      0.9234
# RMW            0.5430     0.3629     1.4962     0.1346     -0.1683      1.2543
# CMA           -0.6403     0.3426    -1.8686     1.9383     -1.3118      0.0313
#
#
#                              해상 운송업 Coefficients
# ==============================================================================
# alpha         -2.2437     1.2851    -1.7460     1.9192     -4.7624      0.2750
# Mkt-RF         1.4992     0.3287     4.5607     0.0000      0.8549      2.1434
# SMB           -0.5810     0.5908    -0.9835     1.6746     -1.7389      0.5769
# HML            0.2511     0.4762     0.5273     0.5980     -0.6822      1.1845
# RMW           -0.8046     0.4972    -1.6181     1.8944     -1.7791      0.1700
# CMA           -0.3138     0.5514    -0.5690     1.4306     -1.3945      0.7670
#
#
#                         연료용 가스 제조 및 배관공급업 Coefficients
# ==============================================================================
# alpha         -0.0768     0.4424    -0.1736     1.1378     -0.9438      0.7902
# Mkt-RF         0.9025     0.1015     8.8949     0.0000      0.7036      1.1013
# SMB           -0.2569     0.1676    -1.5329     1.8747     -0.5854      0.0716
# HML            0.4167     0.1481     2.8145     0.0049      0.1265      0.7069
# RMW            0.2706     0.1710     1.5823     0.1136     -0.0646      0.6058
# CMA            0.1532     0.1597     0.9592     0.3375     -0.1598      0.4662
#
#
#                             항공 여객 운송업 Coefficients
# ==============================================================================
# alpha         -0.3039     0.9327    -0.3258     1.2554     -2.1320      1.5242
# Mkt-RF         1.1447     0.2780     4.1182     0.0000      0.5999      1.6895
# SMB           -0.3866     0.4853    -0.7967     1.5744     -1.3378      0.5646
# HML            0.0946     0.3724     0.2539     0.7996     -0.6354      0.8245
# RMW            0.1591     0.4816     0.3304     0.7411     -0.7848      1.1030
# CMA           -0.0684     0.3924    -0.1743     1.1384     -0.8375      0.7007
#
#
#                     영화, 비디오물, 방송프로그램 제작 및 배급업 Coefficients
# ==============================================================================
# alpha          1.0912     1.1243     0.9706     0.3318     -1.1124      3.2947
# Mkt-RF         0.7936     0.3893     2.0387     0.0415      0.0306      1.5565
# SMB            0.3254     0.4548     0.7154     0.4743     -0.5660      1.2167
# HML           -0.6059     0.3835    -1.5798     1.8858     -1.3576      0.1458
# RMW           -0.3783     0.4691    -0.8065     1.5800     -1.2976      0.5411
# CMA            0.1491     0.4624     0.3225     0.7471     -0.7572      1.0554
#
#
#                            기타 비금속광물 광업 Coefficients
# ==============================================================================
# alpha         -1.4431     1.0568    -1.3656     1.8279     -3.5144      0.6281
# Mkt-RF         1.7853     0.3501     5.0988     0.0000      1.0990      2.4716
# SMB            1.3717     0.6152     2.2297     0.0258      0.1660      2.5774
# HML           -0.7991     0.5212    -1.5331     1.8747     -1.8206      0.2225
# RMW            0.4761     0.6445     0.7387     0.4601     -0.7870      1.7392
# CMA           -0.3341     0.3940    -0.8480     1.6036     -1.1063      0.4381
#
#
#                         자동차용 엔진 및 자동차 제조업 Coefficients
# ==============================================================================
# alpha         -0.3271     0.7781    -0.4204     1.3258     -1.8522      1.1980
# Mkt-RF         0.8032     0.2132     3.7675     0.0002      0.3853      1.2210
# SMB           -0.2833     0.3058    -0.9265     1.6458     -0.8826      0.3160
# HML            0.3912     0.2999     1.3046     0.1920     -0.1965      0.9790
# RMW           -0.0086     0.4759    -0.0182     1.0145     -0.9414      0.9241
# CMA           -0.0699     0.3730    -0.1874     1.1487     -0.8010      0.6612
#
#
#                          수산물 가공 및 저장 처리업 Coefficients
# ==============================================================================
# alpha         -0.7888     0.6881    -1.1464     1.7484     -2.1375      0.5598
# Mkt-RF         1.2358     0.2516     4.9114     0.0000      0.7426      1.7289
# SMB            0.3675     0.3047     1.2062     0.2277     -0.2297      0.9648
# HML           -0.3435     0.2686    -1.2790     1.7991     -0.8699      0.1829
# RMW           -0.2705     0.3635    -0.7441     1.5432     -0.9828      0.4419
# CMA            0.6211     0.4564     1.3610     0.1735     -0.2734      1.5156
#
#
#                               재 보험업 Coefficients
# ==============================================================================
# alpha         -0.0870     0.7389    -0.1177     1.0937     -1.5351      1.3612
# Mkt-RF         0.7892     0.2374     3.3252     0.0009      0.3240      1.2544
# SMB           -0.4137     0.3200    -1.2927     1.8039     -1.0409      0.2135
# HML           -0.1545     0.3069    -0.5034     1.3853     -0.7561      0.4471
# RMW           -0.1472     0.3129    -0.4705     1.3620     -0.7606      0.4661
# CMA            0.1334     0.4759     0.2803     0.7793     -0.7994      1.0662
#
#
#                            플라스틱제품 제조업 Coefficients
# ==============================================================================
# alpha          0.4936     0.4345     1.1361     0.2559     -0.3579      1.3452
# Mkt-RF         1.1923     0.1108     10.758     0.0000      0.9751      1.4095
# SMB            0.5179     0.1886     2.7455     0.0060      0.1482      0.8876
# HML           -0.0561     0.1600    -0.3509     1.2744     -0.3696      0.2574
# RMW            0.3063     0.2019     1.5173     0.1292     -0.0894      0.7019
# CMA            0.4729     0.1940     2.4376     0.0148      0.0927      0.8531
#
#
#                          기타 비금속 광물제품 제조업 Coefficients
# ==============================================================================
# alpha          0.6823     0.6356     1.0734     0.2831     -0.5635      1.9282
# Mkt-RF         0.9626     0.2223     4.3297     0.0000      0.5268      1.3983
# SMB            0.5541     0.3391     1.6340     0.1023     -0.1105      1.2187
# HML            0.0767     0.3654     0.2099     0.8337     -0.6395      0.7929
# RMW            0.3418     0.2974     1.1493     0.2504     -0.2411      0.9246
# CMA            0.2824     0.3682     0.7670     0.4431     -0.4392      1.0040
#
#
#                           기타 운송관련 서비스업 Coefficients
# ==============================================================================
# alpha         -0.1255     0.7294    -0.1720     1.1366     -1.5551      1.3041
# Mkt-RF         1.0989     0.1911     5.7516     0.0000      0.7245      1.4734
# SMB            0.4160     0.2451     1.6971     0.0897     -0.0644      0.8965
# HML            0.0538     0.2867     0.1877     0.8511     -0.5081      0.6158
# RMW           -0.0100     0.3824    -0.0260     1.0208     -0.7594      0.7394
# CMA            0.1498     0.2833     0.5286     0.5971     -0.4055      0.7050
#
#
#                           일반 목적용 기계 제조업 Coefficients
# ==============================================================================
# alpha         -0.5061     0.5874    -0.8615     1.6111     -1.6574      0.6452
# Mkt-RF         1.5743     0.1379     11.414     0.0000      1.3040      1.8446
# SMB           -0.5052     0.2750    -1.8371     1.9338     -1.0442      0.0338
# HML           -0.0990     0.1585    -0.6246     1.4678     -0.4097      0.2117
# RMW           -0.0028     0.2678    -0.0103     1.0082     -0.5276      0.5221
# CMA           -0.1426     0.2256    -0.6321     1.4727     -0.5848      0.2996
#
#
#                          일차전지 및 축전지 제조업 Coefficients
# ==============================================================================
# alpha          0.8236     0.5013     1.6428     0.1004     -0.1590      1.8062
# Mkt-RF         0.8489     0.1379     6.1579     0.0000      0.5787      1.1191
# SMB           -0.5655     0.1831    -3.0878     1.9980     -0.9245     -0.2066
# HML            0.4756     0.1853     2.5663     0.0103      0.1124      0.8389
# RMW           -0.1296     0.2635    -0.4920     1.3773     -0.6461      0.3868
# CMA           -0.0132     0.2294    -0.0575     1.0459     -0.4628      0.4364
#
#
#                           그외 기타 제품 제조업 Coefficients
# ==============================================================================
# alpha          0.8254     1.5600     0.5291     0.5967     -2.2321      3.8829
# Mkt-RF         1.6688     1.2132     1.3756     0.1690     -0.7090      4.0467
# SMB           -0.4742     2.9878    -0.1587     1.1261     -6.3303      5.3819
# HML           -2.9352     1.7611    -1.6666     1.9044     -6.3869      0.5166
# RMW           -2.5047     2.2695    -1.1036     1.7302     -6.9529      1.9435
# CMA           -2.3426     2.2277    -1.0516     1.7070     -6.7088      2.0235
#
#
#                               어로 어업 Coefficients
# ==============================================================================
# alpha          0.4248     0.7012     0.6059     0.5446     -0.9495      1.7992
# Mkt-RF         0.9719     0.2315     4.1985     0.0000      0.5182      1.4256
# SMB            0.1776     0.3636     0.4885     0.6252     -0.5350      0.8903
# HML           -0.1849     0.2857    -0.6471     1.4824     -0.7449      0.3751
# RMW            0.3727     0.3827     0.9740     0.3301     -0.3773      1.1227
# CMA            0.0820     0.5042     0.1626     0.8708     -0.9063      1.0703
#
#
#                                전기업 Coefficients
# ==============================================================================
# alpha         -0.0378     0.5902    -0.0641     1.0511     -1.1947      1.1190
# Mkt-RF         0.9824     0.1528     6.4278     0.0000      0.6828      1.2819
# SMB           -0.2248     0.2380    -0.9445     1.6551     -0.6913      0.2417
# HML            0.3420     0.2435     1.4045     0.1602     -0.1353      0.8194
# RMW            0.1497     0.2913     0.5138     0.6074     -0.4213      0.7206
# CMA            0.3510     0.2916     1.2037     0.2287     -0.2205      0.9225
#
#
#                          비알코올음료 및 얼음 제조업 Coefficients
# ==============================================================================
# alpha          0.7546     0.8670     0.8703     0.3841     -0.9448      2.4540
# Mkt-RF         1.0967     0.2810     3.9034     0.0001      0.5460      1.6473
# SMB           -1.1247     0.3795    -2.9638     1.9970     -1.8685     -0.3810
# HML            0.4094     0.3611     1.1340     0.2568     -0.2982      1.1171
# RMW           -0.1293     0.4203    -0.3076     1.2416     -0.9532      0.6945
# CMA           -0.0316     0.4884    -0.0647     1.0516     -0.9889      0.9257
#
#
#                             생활용품 도매업 Coefficients
# ==============================================================================
# alpha          1.3232     0.8032     1.6473     0.0995     -0.2511      2.8975
# Mkt-RF         1.6587     0.2660     6.2366     0.0000      1.1375      2.1800
# SMB            0.3029     0.2863     1.0581     0.2900     -0.2582      0.8640
# HML            0.0518     0.2657     0.1950     0.8454     -0.4690      0.5726
# RMW           -0.0101     0.3365    -0.0300     1.0239     -0.6696      0.6494
# CMA           -0.0033     0.3713    -0.0089     1.0071     -0.7311      0.7245
#
#
#                       기초 의약물질 및 생물학적 제제 제조업 Coefficients
# ==============================================================================
# alpha          0.5452     1.5093     0.3612     0.7179     -2.4130      3.5035
# Mkt-RF         1.0426     0.4823     2.1616     0.0306      0.0973      1.9880
# SMB           -0.2631     0.6758    -0.3894     1.3030     -1.5876      1.0614
# HML           -0.6508     0.6789    -0.9587     1.6623     -1.9813      0.6798
# RMW            0.8826     0.9590     0.9204     0.3574     -0.9969      2.7622
# CMA            0.5085     0.7281     0.6984     0.4849     -0.9186      1.9357
#
#
#                            1차 비철금속 제조업 Coefficients
# ==============================================================================
# alpha          0.0396     0.5713     0.0693     0.9448     -1.0802      1.1594
# Mkt-RF         1.4643     0.1736     8.4353     0.0000      1.1241      1.8046
# SMB            0.5746     0.2651     2.1672     0.0302      0.0549      1.0942
# HML            0.1138     0.2204     0.5165     0.6055     -0.3181      0.5457
# RMW           -0.0846     0.2485    -0.3405     1.2665     -0.5718      0.4025
# CMA            0.4074     0.2426     1.6794     0.0931     -0.0681      0.8828
#
#
#                             은행 및 저축기관 Coefficients
# ==============================================================================
# alpha          0.1032     0.5318     0.1940     0.8461     -0.9391      1.1455
# Mkt-RF         0.9017     0.1593     5.6611     0.0000      0.5895      1.2138
# SMB           -0.4381     0.2829    -1.5485     1.8785     -0.9926      0.1164
# HML            0.3779     0.2044     1.8486     0.0645     -0.0228      0.7785
# RMW           -0.0172     0.2808    -0.0613     1.0489     -0.5675      0.5331
# CMA           -0.0594     0.2882    -0.2059     1.1632     -0.6243      0.5056
#
#
#                              전기 통신업 Coefficients
# ==============================================================================
# alpha          0.5556     0.5654     0.9827     0.3257     -0.5525      1.6637
# Mkt-RF         0.1682     0.1737     0.9687     0.3327     -0.1721      0.5086
# SMB           -0.1731     0.2543    -0.6805     1.5038     -0.6715      0.3254
# HML           -0.0846     0.2615    -0.3236     1.2538     -0.5972      0.4279
# RMW           -0.1435     0.3280    -0.4376     1.3384     -0.7864      0.4993
# CMA            0.0783     0.2415     0.3241     0.7458     -0.3951      0.5517
#
#
#                        건축자재, 철물 및 난방장치 도매업 Coefficients
# ==============================================================================
# alpha          0.2521     1.6417     0.1536     0.8780     -2.9656      3.4699
# Mkt-RF         1.4306     0.5091     2.8099     0.0050      0.4327      2.4285
# SMB            0.0602     0.6798     0.0885     0.9295     -1.2722      1.3925
# HML           -0.2981     0.5521    -0.5399     1.4107     -1.3803      0.7841
# RMW           -0.4970     0.7734    -0.6426     1.4795     -2.0129      1.0189
# CMA           -0.4092     0.7614    -0.5375     1.4091     -1.9015      1.0830
#
#
#                 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업 Coefficients
# ==============================================================================
# alpha         -0.2803     0.5574    -0.5028     1.3849     -1.3728      0.8123
# Mkt-RF         1.1682     0.1212     9.6416     0.0000      0.9307      1.4057
# SMB            0.3724     0.2474     1.5052     0.1323     -0.1125      0.8574
# HML           -0.7965     0.2686    -2.9653     1.9970     -1.3229     -0.2700
# RMW            0.1823     0.3426     0.5322     0.5946     -0.4891      0.8537
# CMA            0.5031     0.2785     1.8067     0.0708     -0.0427      1.0490
#
#
#                             편조원단 제조업 Coefficients
# ==============================================================================
# alpha          0.6651     0.6297     1.0562     0.2909     -0.5691      1.8992
# Mkt-RF         0.8899     0.1510     5.8929     0.0000      0.5940      1.1859
# SMB            0.1227     0.3189     0.3848     0.7004     -0.5024      0.7478
# HML            0.5851     0.2414     2.4238     0.0154      0.1120      1.0582
# RMW           -0.0679     0.2825    -0.2404     1.1900     -0.6217      0.4858
# CMA            0.2119     0.2771     0.7646     0.4445     -0.3313      0.7550
#
#
#                           영상 및 음향기기 제조업 Coefficients
# ==============================================================================
# alpha          0.3929     1.2424     0.3163     0.7518     -2.0422      2.8280
# Mkt-RF         1.1343     0.2334     4.8603     0.0000      0.6769      1.5917
# SMB            0.9196     0.4866     1.8901     0.0587     -0.0340      1.8733
# HML           -0.7607     0.2997    -2.5385     1.9889     -1.3481     -0.1734
# RMW           -1.1603     0.5447    -2.1301     1.9668     -2.2279     -0.0926
# CMA            0.6684     0.8615     0.7759     0.4378     -1.0201      2.3568
#
#
#                           기타 상품 전문 소매업 Coefficients
# ==============================================================================
# alpha          1.7632     1.1509     1.5320     0.1255     -0.4925      4.0189
# Mkt-RF         0.9510     0.3332     2.8544     0.0043      0.2980      1.6040
# SMB           -0.9147     0.4416    -2.0712     1.9617     -1.7802     -0.0491
# HML            0.0783     0.3778     0.2072     0.8359     -0.6623      0.8188
# RMW           -0.2299     0.4476    -0.5137     1.3925     -1.1073      0.6474
# CMA            0.0387     0.5254     0.0736     0.9413     -0.9911      1.0685
#
#
#                            가정용 기기 제조업 Coefficients
# ...
# ==============================================================================
# alpha          1.8865     2.0724     0.9103     0.3627     -2.1753      5.9484
# Mkt-RF         1.9273     0.5029     3.8320     0.0001      0.9415      2.9130
# SMB           -0.4533     0.7404    -0.6123     1.4597     -1.9045      0.9978
# HML            1.1968     0.8039     1.4887     0.1366     -0.3789      2.7725
# RMW           -1.8716     1.0598    -1.7660     1.9226     -3.9487      0.2055
# CMA            0.1801     0.9978     0.1805     0.8567     -1.7755      2.1357
#
#
#                            신탁업 및 집합투자업 Coefficients
# ==============================================================================
# alpha          0.8634     0.4070     2.1214     0.0339      0.0657      1.6612
# Mkt-RF         0.2998     0.1077     2.7826     0.0054      0.0886      0.5109
# SMB            0.0491     0.1657     0.2962     0.7671     -0.2756      0.3738
# HML            0.0516     0.1417     0.3641     0.7158     -0.2261      0.3292
# RMW           -0.0076     0.1491    -0.0509     1.0406     -0.2999      0.2847
# CMA            0.2017     0.1621     1.2440     0.2135     -0.1161      0.5194
#
#
#                        여행사 및 기타 여행보조 서비스업 Coefficients
# ==============================================================================
# alpha         -0.0345     1.1134    -0.0310     1.0248     -2.2168      2.1477
# Mkt-RF         0.9859     0.2572     3.8333     0.0001      0.4818      1.4900
# SMB           -0.2069     0.5310    -0.3897     1.3032     -1.2477      0.8338
# HML           -0.1345     0.3940    -0.3414     1.2672     -0.9068      0.6377
# RMW           -0.1106     0.4945    -0.2237     1.1770     -1.0799      0.8587
# CMA            0.8111     0.6283     1.2909     0.1968     -0.4204      2.0425
#
#
#                           기타 사업지원 서비스업 Coefficients
# ==============================================================================
# alpha          0.7984     1.4613     0.5464     0.5848     -2.0657      3.6625
# Mkt-RF         0.8333     0.3743     2.2262     0.0260      0.0997      1.5670
# SMB            0.8701     0.8374     1.0390     0.2988     -0.7713      2.5114
# HML           -0.6961     0.6020    -1.1563     1.7524     -1.8761      0.4838
# RMW            1.1333     0.8719     1.2998     0.1937     -0.5756      2.8422
# CMA            0.9811     0.7325     1.3393     0.1805     -0.4547      2.4169
#
#
#                            전기 및 통신 공사업 Coefficients
# ==============================================================================
# alpha          0.5639     0.9017     0.6253     0.5317     -1.2035      2.3312
# Mkt-RF         0.9764     0.3076     3.1742     0.0015      0.3735      1.5793
# SMB           -0.6678     0.4331    -1.5419     1.8769     -1.5168      0.1811
# HML            0.0971     0.3106     0.3126     0.7546     -0.5117      0.7058
# RMW           -0.7557     0.4232    -1.7857     1.9258     -1.5851      0.0738
# CMA           -0.0511     0.4316    -0.1184     1.0942     -0.8971      0.7949
#
#
#                        증기, 냉·온수 및 공기조절 공급업 Coefficients
# ==============================================================================
# alpha         -0.0155     0.8013    -0.0193     1.0154     -1.5859      1.5550
# Mkt-RF         0.9369     0.1904     4.9198     0.0000      0.5636      1.3101
# SMB           -0.7943     0.3393    -2.3409     1.9808     -1.4593     -0.1293
# HML            0.3595     0.3048     1.1795     0.2382     -0.2379      0.9568
# RMW            0.5237     0.3960     1.3224     0.1860     -0.2525      1.2999
# CMA           -0.3717     0.3245    -1.1455     1.7480     -1.0078      0.2643
#
#
#                               음식점업 Coefficients
# ==============================================================================
# alpha          0.2878     0.8752     0.3289     0.7422     -1.4276      2.0033
# Mkt-RF         1.0119     0.2060     4.9125     0.0000      0.6081      1.4156
# SMB           -0.3543     0.3630    -0.9759     1.6709     -1.0657      0.3572
# HML           -0.0878     0.2787    -0.3150     1.2472     -0.6341      0.4585
# RMW           -0.0624     0.4730    -0.1318     1.1049     -0.9894      0.8647
# CMA            0.1287     0.4316     0.2981     0.7656     -0.7172      0.9746
#
#
#                              연료 소매업 Coefficients
# ==============================================================================
# alpha         -3.6032     1.4177    -2.5415     1.9890     -6.3818     -0.8245
# Mkt-RF         1.5450     0.4444     3.4762     0.0005      0.6739      2.4161
# SMB           -0.7312     0.5954    -1.2279     1.7805     -1.8982      0.4359
# HML            0.3162     0.4627     0.6835     0.4943     -0.5906      1.2230
# RMW            0.7002     0.6905     1.0141     0.3105     -0.6532      2.0537
# CMA           -0.9588     0.6613    -1.4499     1.8529     -2.2549      0.3373
#
#
#                              무점포 소매업 Coefficients
# ==============================================================================
# alpha         -0.3259     0.8923    -0.3652     1.2850     -2.0747      1.4229
# Mkt-RF         0.8669     0.3067     2.8268     0.0047      0.2658      1.4679
# SMB           -0.6170     0.3426    -1.8008     1.9283     -1.2885      0.0545
# HML           -0.1183     0.2732    -0.4330     1.3350     -0.6537      0.4171
# RMW           -0.3730     0.4759    -0.7838     1.5669     -1.3058      0.5597
# CMA           -0.5307     0.3713    -1.4294     1.8471     -1.2584      0.1970
#
#
#                            기타 정보 서비스업 Coefficients
# ==============================================================================
# alpha         -0.3049     0.6828    -0.4465     1.3448     -1.6432      1.0334
# Mkt-RF         1.2937     0.1992     6.4959     0.0000      0.9034      1.6840
# SMB           -0.4233     0.2944    -1.4376     1.8495     -1.0003      0.1538
# HML            0.6405     0.2289     2.7982     0.0051      0.1919      1.0891
# RMW            0.2744     0.3147     0.8719     0.3833     -0.3424      0.8911
# CMA           -0.3869     0.3381    -1.1443     1.7475     -1.0496      0.2758
#
#
#                              자동차 판매업 Coefficients
# ==============================================================================
# alpha          0.3598     1.1442     0.3144     0.7532     -1.8829      2.6025
# Mkt-RF         0.8786     0.3581     2.4534     0.0142      0.1767      1.5805
# SMB           -0.7058     0.4287    -1.6462     1.9003     -1.5461      0.1345
# HML            1.0188     0.4152     2.4539     0.0141      0.2051      1.8325
# RMW           -0.0833     0.4599    -0.1811     1.1437     -0.9847      0.8182
# CMA           -1.0625     0.5795    -1.8333     1.9332     -2.1983      0.0734
#
#
#                        합성고무 및 플라스틱 물질 제조업 Coefficients
# ==============================================================================
# alpha         -0.5588     1.0427    -0.5360     1.4080     -2.6025      1.4848
# Mkt-RF         0.9331     0.3303     2.8251     0.0047      0.2858      1.5805
# SMB            0.3292     0.4592     0.7169     0.4735     -0.5709      1.2292
# HML           -0.2085     0.3078    -0.6773     1.5018     -0.8117      0.3947
# RMW            0.2559     0.3973     0.6441     0.5195     -0.5228      1.0347
# CMA           -0.1302     0.4322    -0.3012     1.2367     -0.9772      0.7169
#
#
#                       섬유, 의복, 신발 및 가죽제품 소매업 Coefficients
# ==============================================================================
# alpha          0.0763     0.7997     0.0954     0.9240     -1.4910      1.6436
# Mkt-RF         0.9770     0.2700     3.6189     0.0003      0.4479      1.5061
# SMB           -0.4138     0.2922    -1.4163     1.8433     -0.9865      0.1589
# HML            0.2063     0.2514     0.8206     0.4119     -0.2865      0.6991
# RMW            0.4730     0.4278     1.1057     0.2689     -0.3655      1.3115
# CMA           -0.0941     0.3590    -0.2621     1.2067     -0.7976      0.6095
#
#
#                         가전제품 및 정보통신장비 소매업 Coefficients
# ==============================================================================
# alpha          1.0675     0.8327     1.2819     0.1999     -0.5647      2.6996
# Mkt-RF         0.4515     0.3351     1.3472     0.1779     -0.2054      1.1083
# SMB           -1.1577     0.4438    -2.6089     1.9909     -2.0275     -0.2880
# HML            0.7645     0.2987     2.5593     0.0105      0.1790      1.3500
# RMW            0.0460     0.4605     0.0999     0.9204     -0.8566      0.9487
# CMA           -0.3580     0.4229    -0.8465     1.6027     -1.1868      0.4709
#
#
#                             운송장비 임대업 Coefficients
# ==============================================================================
# alpha          0.7716     1.0056     0.7674     0.4429     -1.1992      2.7425
# Mkt-RF         0.4506     0.2437     1.8490     0.0645     -0.0270      0.9281
# SMB           -0.5307     0.3465    -1.5313     1.8743     -1.2099      0.1485
# HML            0.1690     0.5758     0.2934     0.7692     -0.9596      1.2975
# RMW            0.1603     0.5148     0.3113     0.7556     -0.8488      1.1693
# CMA           -0.2827     0.5079    -0.5566     1.4222     -1.2782      0.7127
#
#
#                             철도장비 제조업 Coefficients
# ==============================================================================
# alpha         -0.7020     0.7101    -0.9886     1.6771     -2.0939      0.6898
# Mkt-RF         0.3410     0.1402     2.4320     0.0150      0.0662      0.6157
# SMB            0.0380     0.3353     0.1133     0.9098     -0.6192      0.6952
# HML            0.3572     0.2802     1.2745     0.2025     -0.1921      0.9064
# RMW            0.3849     0.2973     1.2947     0.1954     -0.1978      0.9677
# CMA           -0.4989     0.3066    -1.6273     1.8963     -1.0997      0.1020
#
#
#                       산업용 농·축산물 및 동·식물 도매업 Coefficients
# ==============================================================================
# alpha         -0.4788     0.6281    -0.7624     1.5542     -1.7098      0.7522
# Mkt-RF         0.2395     0.1513     1.5827     0.1135     -0.0571      0.5361
# SMB            0.1640     0.2260     0.7256     0.4681     -0.2790      0.6069
# HML           -0.1941     0.2341    -0.8291     1.5930     -0.6529      0.2647
# RMW            0.1265     0.2726     0.4639     0.6427     -0.4078      0.6607
# CMA            0.0197     0.3456     0.0569     0.9546     -0.6576      0.6970
#
#
#                          산업용 기계 및 장비 임대업 Coefficients
# ==============================================================================
# alpha         -0.2891     0.6389    -0.4524     1.3490     -1.5414      0.9632
# Mkt-RF         0.2999     0.1308     2.2921     0.0219      0.0435      0.5563
# SMB            0.2643     0.2538     1.0417     0.2976     -0.2330      0.7617
# HML           -0.3216     0.3277    -0.9813     1.6736     -0.9640      0.3207
# RMW            0.3818     0.2720     1.4037     0.1604     -0.1513      0.9149
# CMA           -0.1460     0.3267    -0.4469     1.3450     -0.7863      0.4943
#
#
#                          음·식료품 및 담배 도매업 Coefficients
# ==============================================================================
# alpha         -0.9207     0.4099    -2.2461     1.9753     -1.7241     -0.1173
# Mkt-RF         0.2608     0.0935     2.7878     0.0053      0.0774      0.4441
# SMB           -0.2097     0.1520    -1.3795     1.8323     -0.5076      0.0882
# HML            0.0092     0.2405     0.0382     0.9695     -0.4622      0.4806
# RMW           -0.0255     0.1680    -0.1517     1.1205     -0.3547      0.3037
# CMA            0.0261     0.1976     0.1320     0.8950     -0.3613      0.4135
#
#
#                         일반 및 생활 숙박시설 운영업 Coefficients
# ==============================================================================
# alpha         -0.0507     0.7255    -0.0699     1.0557     -1.4727      1.3713
# Mkt-RF         0.4230     0.2528     1.6735     0.0942     -0.0724      0.9185
# SMB           -0.0719     0.3697    -0.1944     1.1542     -0.7964      0.6527
# HML           -0.0356     0.3456    -0.1030     1.0820     -0.7129      0.6417
# RMW           -0.0072     0.3234    -0.0221     1.0176     -0.6409      0.6266
# CMA            0.4251     0.3147     1.3507     0.1768     -0.1918      1.0419
#
#
#                            의료용 기기 제조업 Coefficients
# ==============================================================================
# alpha          0.5681     0.5041     1.1269     0.2598     -0.4200      1.5561
# Mkt-RF         0.0463     0.0709     0.6531     0.5137     -0.0927      0.1854
# SMB           -0.1697     0.1432    -1.1851     1.7640     -0.4504      0.1110
# HML           -0.2458     0.3080    -0.7980     1.5751     -0.8495      0.3579
# RMW            0.1656     0.3084     0.5370     0.5913     -0.4388      0.7700
# CMA           -0.3076     0.2309    -1.3322     1.8172     -0.7601      0.1449
#
#
#                           개인 및 가정용품 임대업 Coefficients
# ==============================================================================
# alpha          0.0000     0.0000                            0.0000      0.0000
# Mkt-RF         0.0000     0.0000                            0.0000      0.0000
# SMB            0.0000     0.0000                            0.0000      0.0000
# HML            0.0000     0.0000                            0.0000      0.0000
# RMW            0.0000     0.0000                            0.0000      0.0000
# CMA            0.0000     0.0000                            0.0000      0.0000
#
#
#                            건물설비 설치 공사업 Coefficients
# ==============================================================================
# alpha          0.0000     0.0000                            0.0000      0.0000
# Mkt-RF         0.0000     0.0000                            0.0000      0.0000
# SMB            0.0000     0.0000                            0.0000      0.0000
# HML            0.0000     0.0000                            0.0000      0.0000
# RMW            0.0000     0.0000                            0.0000      0.0000
# CMA            0.0000     0.0000                            0.0000      0.0000
#
#
#                         오디오물 출판 및 원판 녹음업 Coefficients
# ==============================================================================
# alpha          0.0000     0.0000                            0.0000      0.0000
# Mkt-RF         0.0000     0.0000                            0.0000      0.0000
# SMB            0.0000     0.0000                            0.0000      0.0000
# HML            0.0000     0.0000                            0.0000      0.0000
# RMW            0.0000     0.0000                            0.0000      0.0000
# CMA            0.0000     0.0000                            0.0000      0.0000
#
#
#                          자연과학 및 공학 연구개발업 Coefficients
# ==============================================================================
# alpha          0.0000     0.0000                            0.0000      0.0000
# Mkt-RF         0.0000     0.0000                            0.0000      0.0000
# SMB            0.0000     0.0000                            0.0000      0.0000
# HML            0.0000     0.0000                            0.0000      0.0000
# RMW            0.0000     0.0000                            0.0000      0.0000
# CMA            0.0000     0.0000                            0.0000      0.0000
# ==============================================================================
#
# Covariance estimator:
# HeteroskedasticCovariance
# See full_summary for complete results

# %% [markdown]
# This provides us with the same result:

# %%
lambdas.mean()
# Out:
# Mkt-RF    0.728946
# SMB       0.418094
# HML      -0.475366
# RMW       0.049192
# CMA      -0.152758
# dtype: float64
